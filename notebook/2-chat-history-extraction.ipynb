# %% [markdown]
# # Overview
#
# **Overview**
#
# This Jupyter notebook connects to a PostgreSQL database instance running in a Cohere Docker container and extracts chat history data for evaluation. The notebook extracts various data points, including user input, conversation IDs, timestamps, message IDs, answers, and contexts.
#
# **Database Connection and Creation of Views**
#
# 1. The notebook connects to the PostgreSQL database instance using `psycopg2` and creates two views:
# 	* `v_user_messages`: contains user input data with columns `agent`, `text`, `conversation_id`, `created_at`, `id`, `tool_plan`, and `position`.
# 	* `v_chatbot_messages`: contains chatbot answer data with columns `agent`, `text`, `conversation_id`, `created_at`, `id`, `tool_plan`, and `position`.
#
# **Data Extraction and Conversion to DataFrames**
#
# 1. The notebook extracts the following data:
# 	* User input: queries `v_user_messages` view and fetches the results, which includes `agent`, `text`, `conversation_id`, `created_at`, and `position`. The data is converted to a DataFrame (`df_question`) using the columns `agent_user`, `question`, `conversation_id`, `question_timestamp`, and `position`.
# 	* Chatbot answers: queries `v_chatbot_messages` view and fetches the results, which includes `agent`, `text`, `conversation_id`, `created_at`, `id`, `tool_plan`, and `position`. The data is converted to a DataFrame (`df_answer`) using the columns `agent_chatbot`, `answer`, `conversation_id`, `answer_timestamp`, `msg_id`, and `position`.
# 	* Contexts: queries `public.documents` table and fetches the results, which includes `text`, `conversation_id`, `message_id`, and `document_id`. The data is converted to a DataFrame (`df_docs`) using the columns `contexts`, `conversation_id`, `msg_id`, and `doc_id`.
# 2. The notebook performs data manipulation:
# 	* Groups `df_docs` by `conversation_id` and `msg_id`, and combines `contexts` as a list. The resulting DataFrame is called `df_contexts`.
# 	* Merges `df_answer` with `df_contexts` using `conversation_id` and `msg_id`. The resulting DataFrame is called `df_answer_contexts`.
# 	* Merges `df_question` with `df_answer_contexts` using `conversation_id` and `position`. The resulting DataFrame is called `df_question_answer_contexts`.
#
# **Serialization and Deserialization of List Column**
#
# The notebook defines functions to serialize and deserialize a list column in a DataFrame:
#
# 1. `serialize_list`: converts a list to a JSON string.
# 2. `deserialize_list`: converts a JSON string back to a list.
# 3. `save_dataframe_with_list_column`: saves a DataFrame with a list column to a CSV file, preserving the list structure.
# 4. `load_dataframe_with_list_column`: loads a DataFrame from a CSV file, restoring the list structure.
#
# **Exporting Data**
#
# The notebook exports the final DataFrame (`df_question_answer_contexts`) to a CSV file for evaluation, using the functions defined above. Additionally, there are examples of filtering the data for specific use cases:
#
# 1. Exporting data for OpenAI deployment test: filters the records with `conversation_id` equal to `388cf42c-9322-4f36-a896-850c98255e64` and exports the data to a CSV file.
# 2. Exporting data for Cohere deployment test: filters the records with `conversation_id` equal to `71785d7b-4e05-4dee-b44d-4b5c025eb034` and exports the data to a CSV file.
# 3. Exporting data for post-production OpenAI deployment test: filters the records with `conversation_id` equal to `8117578e-d06a-4bfd-988f-b2eee28121f1` and exports the data to a CSV file.

# %% [markdown]
# # Connect postgersql instant

# %%
import psycopg2
import sqlalchemy
from sqlalchemy import MetaData, text
import os
from sqlalchemy import create_engine
import pandas as pd

DATABASE_URL = 'postgresql+psycopg2://postgres:postgres@localhost:5432'

engine = sqlalchemy.create_engine(DATABASE_URL, echo=True)

# print("Connection is", engine)

conn = psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    password="postgres"
)

cur = conn.cursor()

# %% [markdown]
# # Create table views

# %%
# Create a table view for user input
create_view = """
                    CREATE OR REPLACE VIEW v_user_messages
                    AS
                    SELECT text, agent, conversation_id, created_at, id, tool_plan, position FROM messages 
                    WHERE agent = 'USER'
                    ORDER BY created_at desc;
"""
# Execute the SQL query
cur.execute(create_view)

# Commit the transaction
conn.commit()

# %%
# Create a table view for system's answers
create_view = """
                    CREATE OR REPLACE VIEW v_chatbot_messages
                    AS
                    SELECT text, agent, conversation_id, created_at, id, tool_plan, position FROM messages 
                    WHERE agent = 'CHATBOT' AND generation_id IS NOT NULL
                    ORDER BY created_at desc;
"""
# Execute the SQL query
cur.execute(create_view)

# Commit the transaction
conn.commit()

# %% [markdown]
# # Query Chat Data

# %% [markdown]
# ## Query user input

# %%
# Get the questions from user
query = """SELECT 
            user_msgs.agent, 
            user_msgs.text,
            user_msgs.conversation_id,
            user_msgs.created_at,
            user_msgs.position
        FROM public.v_user_messages as user_msgs
        ORDER BY user_msgs.created_at desc;"""

# Execute the query
cur.execute(query)

# %%
# Fetch all results from the executed query
user_msg = cur.fetchall()
user_msg
# Out:
# [('USER',
#   "What is the purpose of adding a header image to a Confluence space and how does it enhance the space's visual appeal and welcoming atmosphere?",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 14, 58, 91025),
#   6),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 14, 36, 238785),
#   5),
#  ('USER',
#   'What is the significance of identifying growth areas in self-assessment?',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 14, 18, 132954),
#   4),
#  ('USER',
#   'What services does the Employee Assistance Program (EAP) provide for employees?',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 13, 58, 222883),
#   3),
#  ('USER',
#   'What training programs are offered in data science by Tech Innovators Inc.?',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 13, 41, 76689),
#   2),
#  ('USER',
#   'What resources should be added for new hires in the onboarding process?',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 13, 21, 150545),
#   1),
#  ('USER',
#   "What is Tech Innovators Inc.'s approach to workplace harassment?",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 12, 53, 53868),
#   0),
#  ('USER',
#   "What is the purpose of adding a header image to a Confluence space and how does it enhance the space's visual appeal and welcoming atmosphere?",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 46, 15, 666414),
#   6),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 45, 23, 825829),
#   5),
#  ('USER',
#   'What is the significance of identifying growth areas in self-assessment?',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 45, 2, 27833),
#   4),
#  ('USER',
#   'What services does the Employee Assistance Program (EAP) provide for employees?',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 44, 42, 878027),
#   3),
#  ('USER',
#   'What training programs are offered in data science by Tech Innovators Inc.?',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 44, 2, 99410),
#   2),
#  ('USER',
#   'What resources should be added for new hires in the onboarding process?',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 43, 38, 380908),
#   1),
#  ('USER',
#   "What is Tech Innovators Inc.'s approach to workplace harassment?",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 42, 14, 734331),
#   0),
#  ('USER',
#   "What is the purpose of adding a header image to a Confluence space and how does it enhance the space's visual appeal and welcoming atmosphere?",
#   'c209cc70-d03c-4439-87f9-224cd07d5da1',
#   datetime.datetime(2024, 9, 24, 22, 45, 14, 398757),
#   0),
#  ('USER',
#   "What is the purpose of adding a header image to a Confluence space and how does it enhance the space's visual appeal and welcoming atmosphere?",
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 33, 26, 604824),
#   6),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 31, 31, 585567),
#   5),
#  ('USER',
#   'What is the significance of identifying growth areas in self-assessment?',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 31, 19, 909115),
#   4),
#  ('USER',
#   'What services does the Employee Assistance Program (EAP) provide for employees?',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 31, 3, 216419),
#   3),
#  ('USER',
#   'What training programs are offered in data science by Tech Innovators Inc.?',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 30, 49, 187066),
#   2),
#  ('USER',
#   'What resources should be added for new hires in the onboarding process?',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 30, 33, 479964),
#   1),
#  ('USER',
#   "What is Tech Innovators Inc.'s approach to workplace harassment?",
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 30, 13, 216889),
#   0),
#  ('USER',
#   'What is the purpose of regular HR audits for labor law and policy compliance, and what happens if there is non-compliance?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 22, 41, 616375),
#   8),
#  ('USER',
#   'How is data processed and organized in the RAG application using LangChain?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 22, 23, 648734),
#   7),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 21, 57, 798201),
#   6),
#  ('USER',
#   "What are employees' responsibilities in maintaining compliance with labor laws, company policies, and promoting a fair and legal workplace at Tech Innovators Inc.",
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 21, 37, 346709),
#   5),
#  ('USER',
#   'What role does leadership play in employee engagement at Tech Innovators Inc.?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 21, 23, 941020),
#   4),
#  ('USER',
#   'What types of leaves are offered by Tech Innovators Inc. and how many days of annual leave are employees entitled to?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 57, 575491),
#   3),
#  ('USER',
#   'What are the potential consequences of non-compliance with labor laws or company policies?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 37, 1287),
#   2),
#  ('USER',
#   'What is the significance of emotional and aesthetic labor in the workplace?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 24, 293333),
#   1),
#  ('USER',
#   'What information should be included in the section on compensation and benefits?',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 6, 556136),
#   0),
#  ('USER',
#   'What is the purpose of regular HR audits for labor law and policy compliance, and what happens if there is non-compliance?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 14, 8, 344431),
#   8),
#  ('USER',
#   'How is data processed and organized in the RAG application using LangChain?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 13, 41, 4566),
#   7),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 13, 11, 992906),
#   6),
#  ('USER',
#   "What are employees' responsibilities in maintaining compliance with labor laws, company policies, and promoting a fair and legal workplace at Tech Innovators Inc.?",
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 57, 796881),
#   5),
#  ('USER',
#   'What role does leadership play in employee engagement at Tech Innovators Inc.?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 43, 764102),
#   4),
#  ('USER',
#   'What types of leaves are offered by Tech Innovators Inc. and how many days of annual leave are employees entitled to?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 20, 661262),
#   3),
#  ('USER',
#   'What are the potential consequences of non-compliance with labor laws or company policies?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 4, 788083),
#   2),
#  ('USER',
#   'What is the significance of emotional and aesthetic labor in the workplace?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 11, 52, 139815),
#   1),
#  ('USER',
#   'What information should be included in the section on compensation and benefits?',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 11, 11, 428947),
#   0),
#  ('USER',
#   "What is the purpose of adding a header image to a Confluence space and how does it enhance the space's visual appeal and welcoming atmosphere?",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 52, 305768),
#   6),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 38, 766823),
#   5),
#  ('USER',
#   'What is the significance of identifying growth areas in self-assessment?',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 17, 904776),
#   4),
#  ('USER',
#   'What services does the Employee Assistance Program (EAP) provide for employees?',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 1, 697199),
#   3),
#  ('USER',
#   'What training programs are offered in data science by Tech Innovators Inc.?',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 43, 49, 247020),
#   2),
#  ('USER',
#   'What resources should be added for new hires in the onboarding process?',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 43, 34, 977663),
#   1),
#  ('USER',
#   "What is Tech Innovators Inc.'s approach to workplace harassment?",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 43, 17, 862142),
#   0),
#  ('USER',
#   'How does Tech Innovators Inc. promote employee engagement through collaboration and an engaging work environment?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 48, 844662),
#   8),
#  ('USER',
#   'What steps are needed to extract data from Confluence and create a RAG application using LangChain?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 34, 719956),
#   7),
#  ('USER',
#   'How do employee engagement and disengagement differ in terms of emotional commitment, motivation, and their relation to labor laws?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 21, 461914),
#   6),
#  ('USER',
#   'What mechanisms are in place for reporting violations of labor laws or company policies, and how are these reports investigated to ensure compliance at Tech Innovators Inc.?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 9, 553795),
#   5),
#  ('USER',
#   'What is the purpose of the orientation session at Tech Innovators Inc.?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 58, 669393),
#   4),
#  ('USER',
#   'What is the significance of emotional and aesthetic labor in the workplace?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 46, 211875),
#   3),
#  ('USER',
#   'What forms of unethical behavior are strictly prohibited in the recruitment process of Inc.?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 33, 160119),
#   2),
#  ('USER',
#   'What is the importance of identifying and addressing growth areas in self-assessment?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 11, 906808),
#   1),
#  ('USER',
#   'How does the role of the Senior Director responsible for Analytics Delivery contribute to data-driven decision-making?',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 9, 39, 370481),
#   0)]

# %% [markdown]
# **Convert the retrieved data to a dataframe.**

# %%
# Assign the appropriate column names
user_column_name = ['agent_user', 'question', 'conversation_id', 'question_timestamp', 'position']

# Create a DataFrame
df_question = pd.DataFrame([row for row in user_msg], columns=user_column_name)

# %%
df_question
# Out:
#    agent_user                                           question  \
# 0        USER  What is the purpose of adding a header image t...
# 1        USER  How do employee engagement and disengagement d...
# 2        USER  What is the significance of identifying growth...
# 3        USER  What services does the Employee Assistance Pro...
# 4        USER  What training programs are offered in data sci...
# 5        USER  What resources should be added for new hires i...
# 6        USER  What is Tech Innovators Inc.'s approach to wor...
# 7        USER  What is the purpose of adding a header image t...
# 8        USER  How do employee engagement and disengagement d...
# 9        USER  What is the significance of identifying growth...
# 10       USER  What services does the Employee Assistance Pro...
# 11       USER  What training programs are offered in data sci...
# 12       USER  What resources should be added for new hires i...
# 13       USER  What is Tech Innovators Inc.'s approach to wor...
# 14       USER  What is the purpose of adding a header image t...
# 15       USER  What is the purpose of adding a header image t...
# 16       USER  How do employee engagement and disengagement d...
# 17       USER  What is the significance of identifying growth...
# 18       USER  What services does the Employee Assistance Pro...
# 19       USER  What training programs are offered in data sci...
# 20       USER  What resources should be added for new hires i...
# 21       USER  What is Tech Innovators Inc.'s approach to wor...
# 22       USER  What is the purpose of regular HR audits for l...
# 23       USER  How is data processed and organized in the RAG...
# 24       USER  How do employee engagement and disengagement d...
# 25       USER  What are employees' responsibilities in mainta...
# 26       USER  What role does leadership play in employee eng...
# 27       USER  What types of leaves are offered by Tech Innov...
# 28       USER  What are the potential consequences of non-com...
# 29       USER  What is the significance of emotional and aest...
# 30       USER  What information should be included in the sec...
# 31       USER  What is the purpose of regular HR audits for l...
# 32       USER  How is data processed and organized in the RAG...
# 33       USER  How do employee engagement and disengagement d...
# 34       USER  What are employees' responsibilities in mainta...
# 35       USER  What role does leadership play in employee eng...
# 36       USER  What types of leaves are offered by Tech Innov...
# 37       USER  What are the potential consequences of non-com...
# 38       USER  What is the significance of emotional and aest...
# 39       USER  What information should be included in the sec...
# 40       USER  What is the purpose of adding a header image t...
# 41       USER  How do employee engagement and disengagement d...
# 42       USER  What is the significance of identifying growth...
# 43       USER  What services does the Employee Assistance Pro...
# 44       USER  What training programs are offered in data sci...
# 45       USER  What resources should be added for new hires i...
# 46       USER  What is Tech Innovators Inc.'s approach to wor...
# 47       USER  How does Tech Innovators Inc. promote employee...
# 48       USER  What steps are needed to extract data from Con...
# 49       USER  How do employee engagement and disengagement d...
# 50       USER  What mechanisms are in place for reporting vio...
# 51       USER  What is the purpose of the orientation session...
# 52       USER  What is the significance of emotional and aest...
# 53       USER  What forms of unethical behavior are strictly ...
# 54       USER  What is the importance of identifying and addr...
# 55       USER  How does the role of the Senior Director respo...
#
#                          conversation_id         question_timestamp  position
# 0   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:14:58.091025         6
# 1   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:14:36.238785         5
# 2   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:14:18.132954         4
# 3   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:13:58.222883         3
# 4   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:13:41.076689         2
# 5   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:13:21.150545         1
# 6   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:12:53.053868         0
# 7   388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:46:15.666414         6
# 8   388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:45:23.825829         5
# 9   388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:45:02.027833         4
# 10  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:44:42.878027         3
# 11  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:44:02.099410         2
# 12  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:43:38.380908         1
# 13  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:42:14.734331         0
# 14  c209cc70-d03c-4439-87f9-224cd07d5da1 2024-09-24 22:45:14.398757         0
# 15  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:33:26.604824         6
# 16  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:31:31.585567         5
# 17  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:31:19.909115         4
# 18  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:31:03.216419         3
# 19  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:30:49.187066         2
# 20  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:30:33.479964         1
# 21  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:30:13.216889         0
# 22  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:22:41.616375         8
# 23  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:22:23.648734         7
# 24  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:21:57.798201         6
# 25  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:21:37.346709         5
# 26  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:21:23.941020         4
# 27  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:57.575491         3
# 28  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:37.001287         2
# 29  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:24.293333         1
# 30  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:06.556136         0
# 31  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:14:08.344431         8
# 32  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:13:41.004566         7
# 33  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:13:11.992906         6
# 34  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:57.796881         5
# 35  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:43.764102         4
# 36  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:20.661262         3
# 37  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:04.788083         2
# 38  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:11:52.139815         1
# 39  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:11:11.428947         0
# 40  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:52.305768         6
# 41  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:38.766823         5
# 42  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:17.904776         4
# 43  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:01.697199         3
# 44  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:43:49.247020         2
# 45  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:43:34.977663         1
# 46  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:43:17.862142         0
# 47  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:48.844662         8
# 48  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:34.719956         7
# 49  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:21.461914         6
# 50  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:09.553795         5
# 51  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:58.669393         4
# 52  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:46.211875         3
# 53  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:33.160119         2
# 54  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:11.906808         1
# 55  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:09:39.370481         0

# %% [markdown]
# ## Query system response

# %% [markdown]
# ### Answers

# %%
# Get the questions from user
query = """SELECT 
            chatbot_msgs.agent, 
            chatbot_msgs.text,
            chatbot_msgs.conversation_id,
            chatbot_msgs.created_at,
            chatbot_msgs.id,
            chatbot_msgs.position
        FROM public.v_chatbot_messages as chatbot_msgs
        ORDER BY chatbot_msgs.created_at desc;"""

# Execute the query
cur.execute(query)

# %%
# Fetch all results from the executed query
chatbot_msg = cur.fetchall()
chatbot_msg
# Out:
# [('CHATBOT',
#   "I'm sorry, I could not find any information about the purpose of adding a header image to a Confluence space.",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 15, 0, 653238),
#   '6974c089-42e7-4f32-995c-6f2aaa1f6330',
#   6),
#  ('CHATBOT',
#   "Employee engagement refers to the emotional commitment an employee has towards their organisation and its goals. Engaged employees are enthusiastic about their work, take positive action to further the organisation's reputation and interests, and are motivated to contribute. Employee disengagement is not mentioned in the sources.\n\nThe sources do not refer to labour laws.",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 14, 39, 361201),
#   'a6232328-cdb5-483a-a1ad-18dfaed9d9bf',
#   5),
#  ('CHATBOT',
#   "I'm sorry, I could not find any information about the significance of identifying growth areas in self-assessment.",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 14, 20, 792092),
#   '5f2caa0f-be6b-45c8-aa4b-16e93bec9964',
#   4),
#  ('CHATBOT',
#   'The Employee Assistance Program (EAP) provides confidential support to employees on personal and professional issues. This includes counselling services, legal advice, and financial planning assistance.',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 14, 0, 911699),
#   'c93def44-2a45-42c6-a851-d2a17c71a60c',
#   3),
#  ('CHATBOT',
#   'Tech Innovators Inc. offers training programs in data science, including an Introduction to Data Science course that covers fundamental concepts such as data exploration, data cleaning, and basic statistical analysis. There is also a Data Analysis and Visualization course that teaches employees to analyse and visualise data using tools. These programs are designed to empower the workforce with the skills and knowledge needed to drive innovation and achieve excellence.',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 13, 43, 733127),
#   '3e5b362a-aaeb-447e-9ce6-65459534b6dd',
#   2),
#  ('CHATBOT',
#   "I'm sorry, I could not find any information about resources for new hires in the onboarding process. However, I can tell you that the onboarding process includes a comprehensive orientation program to integrate new hires smoothly.",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 13, 23, 480350),
#   'dda7c255-077b-4c3e-b7ef-b68c4c756e61',
#   1),
#  ('CHATBOT',
#   'Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment, you should report it immediately to HR or your manager. The company will then conduct a thorough investigation and take appropriate action. Regular training is also conducted to ensure all employees understand and adhere to EEO principles.',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   datetime.datetime(2024, 9, 25, 16, 12, 55, 734782),
#   'c5f9334c-0ee0-4ce7-9d61-b08ea4d63ce2',
#   0),
#  ('CHATBOT',
#   '[openai]: Adding a header image to a Confluence space serves several purposes that enhance both its visual appeal and the overall user experience. Here are the key benefits:\n\n1. **Visual Identity**: A header image helps establish a unique visual identity for the space. It can reflect the theme, purpose, or culture of the team or project, making the space more recognizable and memorable.\n\n2. **Engagement**: A well-chosen header image can capture the attention of users, making the space feel more inviting and engaging. This can encourage team members to explore the content more thoroughly.\n\n3. **Branding**: For organizations, incorporating branding elements such as logos or color schemes in the header image can reinforce the company’s identity and values, creating a cohesive look across different spaces.\n\n4. **Emotional Connection**: A visually appealing header can evoke positive emotions and create a welcoming atmosphere. This is particularly important in collaborative environments where team morale and cohesion are vital.\n\n5. **Contextual Relevance**',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 46, 26, 820127),
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   6),
#  ('CHATBOT',
#   "[openai]: Employee engagement and disengagement represent opposite ends of the emotional commitment spectrum within the workplace. Here are the key differences between the two:\n\n1. **Emotional Commitment**:\n   - **Engaged Employees**: They exhibit a strong emotional commitment to their organization and its goals. This commitment drives them to be enthusiastic about their work, actively contributing to the organization's success and reputation.\n   - **Disengaged Employees**: In contrast, disengaged employees often feel disconnected from their work and the organization. They lack emotional investment, which can lead to apathy and a diminished sense of belonging.\n\n2. **Motivation**:\n   - **Engaged Employees**: These individuals are motivated to perform well and take initiative in their roles. Their enthusiasm often translates into higher productivity and a proactive approach to problem-solving.\n   - **Disengaged Employees**: Disengaged employees typically show lower levels of motivation. They may do the bare minimum required, resulting in decreased productivity and a lack of innovation or",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 45, 42, 33713),
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   5),
#  ('CHATBOT',
#   "[openai]: Identifying growth areas in self-assessment is significant for several reasons:\n\n1. **Personal Development**: Recognizing areas for improvement allows individuals to focus their efforts on developing skills and competencies that will enhance their performance and career prospects.\n\n2. **Goal Setting**: Understanding one's strengths and weaknesses helps in setting realistic and achievable goals. This targeted approach can lead to more effective personal and professional development plans.\n\n3. **Increased Self-Awareness**: Self-assessment fosters greater self-awareness, enabling individuals to understand their behaviors, motivations, and the impact they have on others. This awareness is crucial for personal growth and effective interpersonal relationships.\n\n4. **Feedback Utilization**: Identifying growth areas encourages individuals to seek feedback from peers, mentors, or supervisors, which can provide valuable insights and perspectives that may not be apparent through self-reflection alone.\n\n5. **Career Advancement**: By focusing on growth areas, individuals can enhance their qualifications and readiness for new opportunities, making them more competitive in",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 45, 13, 526038),
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   4),
#  ('CHATBOT',
#   '[openai]: The Employee Assistance Program (EAP) at Tech Innovators Inc. provides a variety of confidential support services for employees dealing with personal and professional issues. These services include:\n\n1. **Counseling Services**: Professional counseling for mental health concerns, stress management, and personal challenges.\n2. **Legal Advice**: Access to legal resources and consultations for various legal matters.\n3. **Financial Planning Assistance**: Support for financial issues, including budgeting, debt management, and retirement planning.\n4. **Wellness Programs**: Resources aimed at promoting overall health and well-being.\n\nEmployees can find more information and contact details for the EAP on the HR portal.',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 44, 54, 894356),
#   '3a4e9d87-5af5-4763-bcaf-f998c79b2105',
#   3),
#  ('CHATBOT',
#   '[openai]: Tech Innovators Inc. offers a range of training programs in data science to help employees build expertise in this critical area. These programs are designed to enhance skills in data-driven decision-making and gaining insights from complex datasets. While specific courses are not detailed in the provided information, the training typically includes workshops, seminars, and access to specialized online courses from platforms like Coursera, edX, and Udacity. This approach ensures that employees are well-equipped to leverage data science in their roles effectively.',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 44, 14, 135242),
#   'dd7dfc74-c310-45e9-a95b-67bd881f03ec',
#   2),
#  ('CHATBOT',
#   '[openai]: To enhance the onboarding process for new hires at Tech Innovators Inc., the following resources could be added:\n\n1. **Comprehensive Onboarding Checklist**: A detailed checklist that outlines all the steps new hires need to complete during their first week, including paperwork, training sessions, and introductions.\n\n2. **Mentorship Program**: While mentorship is mentioned, formalizing this program with structured goals and regular check-ins could provide additional support.\n\n3. **Online Resource Hub**: A centralized online platform where new hires can access training materials, company policies, and FAQs about their roles and the company culture.\n\n4. **Social Integration Activities**: Organizing informal gatherings or team-building activities to help new hires connect with their colleagues and foster a sense of belonging.\n\n5. **Feedback Mechanism**: Establishing a system for new hires to provide feedback on their onboarding experience, which can help improve the process for future employees.\n\n6. **Health and Wellness Resources**: Information about mental health resources, wellness',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 43, 54, 241425),
#   '57295bde-27bc-4e49-9cc9-2f73a6374a46',
#   1),
#  ('CHATBOT',
#   '[openai]: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. The company encourages employees to report any instances of harassment they experience or witness immediately to Human Resources (HR) or their manager. Upon receiving a report, Tech Innovators Inc. commits to conducting a thorough investigation and taking appropriate action based on the findings. The organization is dedicated to maintaining a safe and supportive environment for all employees, ensuring compliance with anti-harassment and anti-discrimination policies.',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   datetime.datetime(2024, 9, 25, 15, 42, 39, 701319),
#   '62e3c8ea-710e-4ef4-b346-8ac0756e4953',
#   0),
#  ('CHATBOT',
#   "[openai]: The purpose of adding a header image to a Confluence space is to enhance its visual appeal and create a more inviting atmosphere for visitors. A well-chosen header image can capture the essence of the team's work or the project's theme, making the space feel more personalized and engaging. This visual element helps to draw users in, making them more likely to explore the content within the space. Additionally, a header image can serve as a branding tool, reinforcing the identity of the team or project, and providing a cohesive look that aligns with the overall goals of the space.",
#   'c209cc70-d03c-4439-87f9-224cd07d5da1',
#   datetime.datetime(2024, 9, 24, 22, 45, 26, 109017),
#   '2c13f405-00a5-4c3e-8904-1eb98694679c',
#   0),
#  ('CHATBOT',
#   "I'm sorry, I couldn't find any information about the purpose of adding a header image to a Confluence space, or how it might enhance the space's visual appeal and welcoming atmosphere.",
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 33, 29, 281308),
#   '558aa359-e8e9-420b-82be-ec64519c5cbb',
#   6),
#  ('CHATBOT',
#   "Employee engagement refers to the emotional commitment an employee has towards their organisation and its goals. Engaged employees are enthusiastic about their work, take positive action to further the organisation's reputation and interests, and are motivated to contribute. However, I couldn't find any information about how employee disengagement differs in these terms, or how either of these concepts relate to labour laws.",
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 31, 34, 146670),
#   '7ea6dd99-b598-43af-b1c6-34c294a975a8',
#   5),
#  ('CHATBOT',
#   "I'm sorry, I couldn't find any information about the significance of identifying growth areas in self-assessment.",
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 31, 22, 234875),
#   '0aac496d-6960-416d-83e5-4e5dd6c3d7b5',
#   4),
#  ('CHATBOT',
#   'The Employee Assistance Program (EAP) provides confidential support for employees on personal and professional issues. This includes counselling services, legal advice, and financial planning assistance.',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 31, 5, 227123),
#   '2a766f13-19b8-4199-bd20-9acb70ac2fd9',
#   3),
#  ('CHATBOT',
#   'Tech Innovators Inc. offers training programs in data science, including an Introduction to Data Science course. This course covers fundamental concepts such as data exploration, data cleaning, and basic statistical analysis. There is also a Data Analysis and Visualization program, which teaches employees to analyse and visualise data using tools.',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 30, 51, 944807),
#   '535e0a18-7e13-46e5-8d67-aed6bca71dbb',
#   2),
#  ('CHATBOT',
#   "I'm sorry, I couldn't find any information about resources for new hires in the onboarding process. However, I can tell you that Tech Innovators Inc. offers a comprehensive orientation program to integrate new hires smoothly.",
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 30, 36, 960195),
#   'e9042617-d990-4f3b-8e0c-5a765da17c7e',
#   1),
#  ('CHATBOT',
#   'Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment, you should report it immediately to HR or your manager. The company will then conduct a thorough investigation and take appropriate action. Tech Innovators Inc. also conducts regular training to ensure all employees understand and adhere to EEO principles.',
#   '3dc7b09b-f7de-40f0-a7f0-1a8d46981531',
#   datetime.datetime(2024, 9, 24, 22, 30, 15, 613587),
#   '5cb6e630-1f81-466b-a351-f4ee7dd29f6d',
#   0),
#  ('CHATBOT',
#   'Regular HR audits are conducted to ensure that employees and managers understand and comply with labor laws and company policies. Internal audits are performed by the HR department, focusing on payroll, benefits, and employment practices. Additionally, periodic external audits are carried out by third-party consultants to verify compliance and identify areas for improvement. If non-compliance is found, employees may face disciplinary actions, up to and including termination of employment.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 22, 45, 332887),
#   '99bcb13a-d816-4f11-a229-260411fc6ad6',
#   8),
#  ('CHATBOT',
#   'Sorry, I could not find any information about how data is processed and organized in the RAG application using LangChain.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 22, 25, 903597),
#   '6deab777-e339-4b13-b261-3a233e60f298',
#   7),
#  ('CHATBOT',
#   'Employee engagement is characterized by motivation and commitment, while disengaged employees may feel disconnected and unmotivated. To promote engagement, Tech Innovators Inc. involves employees in decision-making and fosters a supportive culture where employees feel valued and respected. Employees are responsible for adhering to labor laws and company policies, with a duty to report any violations. Failure to comply may result in disciplinary action and impact employment status.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 22, 0, 752513),
#   'd929a278-9e27-42d9-b172-cd299fec2c04',
#   6),
#  ('CHATBOT',
#   "Employees at Tech Innovators Inc. are responsible for familiarizing themselves with labor laws and company policies. They are encouraged to actively participate in upholding compliance standards through training, monitoring, and proactive measures, contributing to the company's success and a fair and legal workplace.",
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 21, 40, 485097),
#   '3e45f825-7d55-48b9-b743-2f6e6ff735f2',
#   5),
#  ('CHATBOT',
#   'Sorry, I could not find any information about the role of leadership in employee engagement at Tech Innovators Inc.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 21, 26, 98442),
#   '81b7e1dc-e5d0-4a78-932c-12ee91b1debb',
#   4),
#  ('CHATBOT',
#   'Tech Innovators Inc. offers various types of leave, including annual leave, sick leave, maternity/paternity leave, and compassionate leave. Employees are entitled to 20 days of paid annual leave per year. New employees accrue 10 days of vacation time per year, increasing to 15 days after five years of service. Employees are also entitled to 5 or 10 days of paid sick leave per year, depending on the source.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 21, 0, 323130),
#   '4b3f833e-c31d-4ca6-8488-6ff4ef46e076',
#   3),
#  ('CHATBOT',
#   'Non-compliance with labor laws or company policies may result in disciplinary action, up to and including termination of employment. The company follows a progressive discipline approach, where disciplinary actions are determined based on the severity of the violation and the circumstances surrounding the incident. Failure to comply with labor laws can also result in legal penalties, including fines.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 39, 290190),
#   'a601b2c2-0fd9-41b2-9500-857d6b590e14',
#   2),
#  ('CHATBOT',
#   'Emotional and aesthetic labor involves managing emotions and appearances to meet organizational expectations. While this can enhance customer experiences, it can also be taxing on employees.',
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 26, 958788),
#   'ea955e42-5db6-459b-a390-920164db800c',
#   1),
#  ('CHATBOT',
#   "Tech Innovators Inc. strives to provide comprehensive payroll and benefits management to ensure that all employees are compensated fairly and provided with competitive benefits. Injured employees must report their injury to their supervisor immediately and complete a workers' compensation claim form. The company ensures timely processing of claims and payment of benefits as required by law.",
#   '71189b05-eb1c-4c08-b4fc-7d90cc9f3b96',
#   datetime.datetime(2024, 9, 18, 18, 20, 9, 7778),
#   '3e38e220-7904-4667-899b-a2495fd4d9a0',
#   0),
#  ('CHATBOT',
#   'HR audits are conducted regularly by the HR department at Tech Innovators Inc. to ensure that employees and managers understand and comply with labour laws and company policies. These audits cover payroll, benefits and employment practices. External audits are also performed periodically by third-party consultants. \n\nNon-compliance with labour laws or company policies can result in disciplinary action being taken, which may lead to termination. The severity of the violation determines the disciplinary action, and the company follows a progressive discipline approach. Failure to comply can also result in legal consequences, such as fines.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 14, 10, 47930),
#   '0aadd2ab-c0d5-40b5-ac98-7950f84152a0',
#   8),
#  ('CHATBOT',
#   'The RAG application uses the LangChain framework, which involves training the application on custom data. A step-by-step guide to creating such an application is available; it details how data is processed and organised. The application combines retrieval-based methods with generative models.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 13, 42, 283709),
#   '51f57415-f2cf-4b63-bdfe-d1e852aa9a98',
#   7),
#  ('CHATBOT',
#   "Employee engagement refers to the emotional commitment employees have towards their organisation and its goals. Engaged employees are enthusiastic about their work and motivated to contribute to the organisation's reputation and interests. Measuring employee engagement involves assessing factors like job satisfaction and commitment, which can be done through regular surveys. \n\nI could not find any information on employee disengagement and how this differs from engagement in terms of emotional commitment and motivation and their relation to labour laws.",
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 13, 13, 837793),
#   'ffa56b29-5b36-4f13-a34e-1ab113ccfbb6',
#   6),
#  ('CHATBOT',
#   "Employees of Tech Innovators Inc. are responsible for upholding the company's commitment to fostering a diverse and inclusive workplace and its recruitment policies, which aim to ensure equal opportunities for all candidates. The company strives to build a dynamic and innovative team, centred around continuous improvement and adherence to ethical standards.",
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 59, 118411),
#   '70d6e365-6dbd-4c5f-b2ff-467a6462cf05',
#   5),
#  ('CHATBOT',
#   'Leadership plays an important role in employee engagement at Tech Innovators Inc. The company adopts a collaborative approach to employment relations and engagement, which involves encouraging open and transparent communication between employees and management.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 45, 69947),
#   '6b95df96-65d4-43a6-8e41-aba045d28b42',
#   4),
#  ('CHATBOT',
#   'Tech Innovators Inc. offers several types of leave, including paid time off for vacation, personal time and illness, which employees accrue based on their length of service. This paid time off is in addition to the 10 paid holidays observed by the company each year. The company also offers leaves for personal illness or to care for an immediate family member.\n\nEmployees at Tech Innovators Inc. are entitled to accrue annual leave based on their service length.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 22, 259627),
#   'cca2d60c-5826-4b71-a41e-c5df50cef119',
#   3),
#  ('CHATBOT',
#   'Non-compliance with labour laws or company policies can result in disciplinary action being taken, which may be severe enough to result in termination of employment. Legal consequences of failing to comply with labour laws can include fines. Disciplinary actions are usually determined based on the severity of the violation. Companies often follow a progressive discipline approach.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 12, 6, 459099),
#   '7d63cf25-146b-4912-a0e0-ebfa7afeaf83',
#   2),
#  ('CHATBOT',
#   'Emotional and aesthetic labour involves managing emotions and appearances to meet organisational expectations. This can enhance customer experiences but can also be emotionally draining for employees. Therefore, it is important to support employees who have to expend this kind of labour.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 11, 53, 741072),
#   '3ad7f0e5-156b-4db7-89a7-323b408ed67d',
#   1),
#  ('CHATBOT',
#   'The section on compensation and benefits should include information on payroll and benefits policies. These policies should aim to compensate employees fairly and provide them with competitive benefits. The section might also specify how employees are informed of any changes to these policies.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   datetime.datetime(2024, 9, 18, 18, 11, 13, 580652),
#   '56389028-d5da-4079-8d62-efe3f223c93c',
#   0),
#  ('CHATBOT',
#   '[openai]: Adding a header image to a Confluence space serves several important purposes. Firstly, it enhances the visual appeal of the space, making it more attractive and engaging for visitors. A well-chosen header image can reflect the theme or purpose of the space, creating a cohesive look and feel that aligns with the content presented.\n\nSecondly, a header image contributes to a welcoming atmosphere. It can evoke positive emotions and set the tone for the user experience, making visitors feel more comfortable and inclined to explore the content. By providing a visually appealing introduction, the header image helps to draw users in and encourages them to interact with the space more actively.\n\nOverall, incorporating a header image is an effective way to improve user engagement and create a more inviting environment within a Confluence space.',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 45, 1, 526985),
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   6),
#  ('CHATBOT',
#   "[openai]: Employee engagement and disengagement differ significantly in several key areas, including emotional commitment, motivation, and their implications for labor laws.\n\n1. **Emotional Commitment**: \n   - **Engaged Employees**: These individuals exhibit a strong emotional commitment to their organization. They feel a sense of belonging and are aligned with the company's goals and values. This emotional connection often leads to increased loyalty and a willingness to go above and beyond in their roles.\n   - **Disengaged Employees**: In contrast, disengaged employees feel disconnected from their organization. They may lack enthusiasm for their work and show little emotional investment in their tasks or the company's success. This detachment can lead to lower productivity and a negative workplace atmosphere.\n\n2. **Motivation**:\n   - **Engaged Employees**: They are typically motivated and committed to their work, often driven by intrinsic factors such as personal growth, recognition, and a desire to contribute meaningfully to the organization. Their motivation can lead to higher levels of",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 49, 6283),
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   5),
#  ('CHATBOT',
#   '[openai]: Identifying growth areas in self-assessment is significant for several reasons:\n\n1. **Personal Development**: Recognizing areas for improvement allows individuals to focus on their personal and professional growth. This targeted approach helps in setting specific goals and developing skills that are essential for career advancement.\n\n2. **Enhanced Performance**: By identifying weaknesses, individuals can work on them, leading to improved performance in their current roles. This can result in better job satisfaction and increased productivity.\n\n3. **Feedback Utilization**: Self-assessment encourages individuals to reflect on feedback received from peers and supervisors. This reflection can lead to a deeper understanding of one’s strengths and weaknesses, fostering a culture of continuous improvement.\n\n4. **Career Planning**: Understanding growth areas can assist in career planning and development. Individuals can align their skills with future career aspirations, making informed decisions about training and development opportunities.\n\n5. **Increased Self-Awareness**: Self-assessment promotes self-awareness, which is crucial for personal growth. Being',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 27, 890469),
#   '77467460-8250-4984-b81b-e40b3e576435',
#   4),
#  ('CHATBOT',
#   '[openai]: The Employee Assistance Program (EAP) provides a variety of services for employees, including:\n\n1. **Counseling Services**: Confidential counseling for personal and professional issues.\n2. **Legal Advice**: Access to legal resources and advice for various legal matters.\n3. **Financial Planning Assistance**: Support and guidance on financial planning and management.\n\nEmployees can find contact information for the EAP on the HR portal.',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 44, 9, 997083),
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   3),
#  ('CHATBOT',
#   '[openai]: Tech Innovators Inc. offers a range of training programs focused on data science to help employees develop expertise in this critical area. These programs typically include:\n\n1. **Data Analysis and Visualization**: Training on how to analyze data and create visual representations to communicate insights effectively.\n\n2. **Machine Learning**: Courses that cover the fundamentals of machine learning, including algorithms and their applications in business.\n\n3. **Statistical Methods**: Instruction on statistical techniques that are essential for data analysis and interpretation.\n\n4. **Big Data Technologies**: Training on tools and technologies used to manage and analyze large datasets, such as Hadoop and Spark.\n\n5. **Data-Driven Decision Making**: Programs that focus on how to leverage data for strategic decision-making within organizations.\n\n6. **AI and Data Science Integration**: Courses that explore how artificial intelligence can be integrated with data science practices to enhance business outcomes.\n\nThese training programs are designed to equip employees with the necessary skills to make data-driven decisions and gain insights from',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 43, 58, 972825),
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   2),
#  ('CHATBOT',
#   "[openai]: For new hires in the onboarding process, several resources can be beneficial to ensure a smooth transition into the company. Here are some suggestions:\n\n1. **Onboarding FAQs**: A comprehensive list of frequently asked questions can help new hires quickly find answers to common queries.\n\n2. **Meeting Notes**: Providing access to notes from important meetings can help new employees understand the company's current projects and priorities.\n\n3. **Training Materials**: Resources that include training manuals, guides, and links to online courses can assist new hires in developing the skills necessary for their roles.\n\n4. **Mentorship Programs**: Information about mentorship opportunities can help new employees connect with experienced team members for guidance and support.\n\n5. **Diversity and Inclusion Resources**: Materials that outline the company's diversity and inclusion initiatives can help new hires understand the workplace culture and expectations.\n\n6. **Contact Information**: A list of key contacts, including HR representatives and team leads, can facilitate communication and support.\n\n7. **Company Policies**",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 43, 46, 27698),
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   1),
#  ('CHATBOT',
#   "[openai]: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. The company does not tolerate harassment or discrimination of any kind, including sexual harassment. If an employee experiences or witnesses harassment, they are encouraged to report it in accordance with the company's policies. This approach is part of their commitment to promoting a fair and legal workplace, adhering to Equal Employment Opportunity (EEO) principles.",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   datetime.datetime(2024, 9, 17, 21, 43, 29, 170986),
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   0),
#  ('CHATBOT',
#   '[openai]: Tech Innovators Inc. promotes employee engagement through collaboration and an engaging work environment in several key ways:\n\n1. **Team Collaboration**: The company fosters a culture of teamwork by encouraging cross-departmental collaboration. This approach allows employees to work together on projects, share ideas, and leverage diverse perspectives, which enhances problem-solving and innovation.\n\n2. **Open Communication**: Tech Innovators Inc. emphasizes open lines of communication, where employees feel comfortable sharing their thoughts and feedback. Regular meetings, brainstorming sessions, and feedback loops help create a transparent environment that values employee input.\n\n3. **Flexible Workspaces**: The organization designs its physical and virtual workspaces to be conducive to collaboration. This includes creating areas for team discussions, brainstorming, and social interactions, which can help build relationships and strengthen team dynamics.\n\n4. **Engaging Activities**: Tech Innovators Inc. organizes team-building activities, workshops, and social events that promote engagement and camaraderie among employees. These activities help to break down barriers',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 58, 87223),
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   8),
#  ('CHATBOT',
#   '[openai]: To extract data from Confluence and create a Retrieval-Augmented Generation (RAG) application using the LangChain framework, you can follow these steps:\n\n1. **Access Confluence Data**:\n   - Use the Confluence API to connect to your Confluence instance. You may need to authenticate using API tokens or OAuth, depending on your Confluence setup.\n   - Alternatively, export the necessary data from Confluence in a suitable format (e.g., JSON, CSV).\n\n2. **Install Required Libraries**:\n   - Ensure you have the necessary libraries installed. You will need:\n     - LangChain: For building the RAG application.\n     - OpenAI or Hugging Face Transformers: For the generative model.\n     - Pinecone or another vector database: For storing and retrieving embeddings.\n\n   You can install these libraries using pip:\n   ```bash\n   pip install langchain openai pinecone-client\n   ```\n\n3. **Data Preprocessing**:\n   - Clean and preprocess',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 45, 436811),
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   7),
#  ('CHATBOT',
#   '[openai]: Employee engagement and disengagement differ significantly in terms of emotional commitment, motivation, and their implications for labor laws.\n\n1. **Emotional Commitment**: Engaged employees exhibit a strong emotional commitment to their organization. They feel a sense of belonging and connection, which drives them to contribute positively to the workplace. In contrast, disengaged employees often feel disconnected and unmotivated, lacking the emotional investment that fosters productivity and loyalty.\n\n2. **Motivation**: Engaged employees are typically motivated to go above and beyond their job requirements, driven by a desire to achieve organizational goals and personal growth. They are more likely to take initiative and participate actively in their roles. Conversely, disengaged employees may show minimal effort, leading to lower productivity and a lack of enthusiasm for their work. This disengagement can result in a negative impact on team dynamics and overall organizational performance.\n\n3. **Relation to Labor Laws**: Disengagement can sometimes lead to violations of labor laws, as disengaged employees may feel',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 32, 417639),
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   6),
#  ('CHATBOT',
#   '[openai]: At Tech Innovators Inc., there are specific mechanisms in place for reporting violations of labor laws or company policies. Employees can utilize a confidential reporting system that allows them to report any concerns or violations without fear of retaliation. This system ensures that employees feel safe and supported when bringing issues to light.\n\nOnce a report is made, the investigation process is initiated. This typically involves the following steps:\n\n1. **Acknowledgment of Report**: The company acknowledges receipt of the report and assures the employee that it will be taken seriously.\n\n2. **Investigation**: A designated team or individual conducts a thorough investigation into the reported issue. This may include interviewing the reporting employee, witnesses, and reviewing relevant documents or evidence.\n\n3. **Confidentiality**: Throughout the investigation, confidentiality is maintained to protect the identities of those involved and the integrity of the investigation.\n\n4. **Findings and Action**: After the investigation is complete, findings are documented, and appropriate actions are taken based on the results.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 18, 736750),
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   5),
#  ('CHATBOT',
#   '[openai]: The purpose of the orientation session at Tech Innovators Inc. is to provide new employees with essential information about the company, its culture, policies, and procedures. This session aims to help newcomers acclimate to their roles, understand the organizational structure, and familiarize themselves with the tools and resources available to them. Additionally, it serves to introduce new hires to their colleagues and promote a sense of belonging within the company. Overall, the orientation session is designed to ensure that employees feel prepared and supported as they begin their journey at Tech Innovators Inc.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 18, 7, 629822),
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   4),
#  ('CHATBOT',
#   '[openai]: Emotional and aesthetic labor play a significant role in the workplace for several reasons:\n\n1. **Enhancing Customer Experience**: Employees who engage in emotional and aesthetic labor often create a more positive and engaging experience for customers. By managing their emotions and appearances, they can foster a welcoming atmosphere that encourages customer satisfaction and loyalty.\n\n2. **Organizational Expectations**: Many organizations expect employees to adhere to specific emotional and aesthetic standards to maintain a brand image. This alignment can enhance the overall reputation of the company and contribute to its success.\n\n3. **Employee Well-being**: While emotional and aesthetic labor can enhance customer interactions, it can also be taxing on employees. The pressure to consistently manage emotions and appearances can lead to burnout if not balanced with adequate support and a healthy work-life balance.\n\n4. **Team Dynamics**: Emotional labor can influence team dynamics and collaboration. Employees who effectively manage their emotions can contribute to a more harmonious work environment, fostering teamwork and cooperation.\n\n5. **Professional Development**',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 55, 927941),
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   3),
#  ('CHATBOT',
#   "[openai]: In the recruitment process of Inc., several forms of unethical behavior are strictly prohibited to maintain integrity and transparency. These include:\n\n1. **Discrimination**: Any form of discrimination based on race, color, religion, sex, national origin, age, disability, or genetic information is not tolerated.\n\n2. **Misrepresentation**: Providing false information about candidates or the job itself, including qualifications, responsibilities, or company policies, is considered unethical.\n\n3. **Nepotism and Favoritism**: Favoring relatives or friends in hiring decisions, rather than selecting candidates based on merit, is strictly prohibited.\n\n4. **Bribery and Corruption**: Engaging in bribery or corrupt practices to influence hiring decisions undermines the integrity of the recruitment process.\n\n5. **Violation of Privacy**: Disregarding candidates' privacy rights by improperly accessing or using personal information without consent is unethical.\n\n6. **Coercion**: Pressuring candidates to accept job offers or to provide personal",
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 42, 639361),
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   2),
#  ('CHATBOT',
#   "[openai]: Identifying and addressing growth areas in self-assessment is crucial for several reasons:\n\n1. **Personal Development**: Recognizing areas for improvement allows individuals to focus on their weaknesses and develop skills that enhance their overall performance. This targeted approach to self-improvement can lead to greater competence in both personal and professional settings.\n\n2. **Goal Setting**: Understanding one's growth areas helps in setting realistic and achievable goals. By knowing where improvement is needed, individuals can create specific, measurable objectives that guide their development efforts.\n\n3. **Enhanced Performance**: Addressing growth areas can lead to improved performance in various tasks and responsibilities. By working on weaknesses, individuals can become more effective in their roles, contributing positively to their teams and organizations.\n\n4. **Increased Confidence**: As individuals identify and work on their growth areas, they often experience a boost in confidence. Overcoming challenges and improving skills can lead to a greater sense of self-efficacy and motivation.\n\n5. **Feedback Utilization**:",
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 17, 21, 233268),
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   1),
#  ('CHATBOT',
#   "[openai]: The role of the Senior Director responsible for Analytics Delivery is pivotal in fostering data-driven decision-making within Tech Innovators Inc. This position involves several key contributions:\n\n1. **Strategic Vision**: The Senior Director sets a strategic vision for analytics initiatives, ensuring that data analytics aligns with the company's overall goals and objectives. This vision helps guide decision-making processes across various departments.\n\n2. **Technical Expertise**: By leveraging technical knowledge, the Senior Director can implement advanced analytics tools and methodologies. This expertise enables the organization to extract meaningful insights from data, which can inform strategic decisions.\n\n3. **Leadership Skills**: The Senior Director leads teams in developing and executing analytics projects. Effective leadership fosters collaboration among team members and encourages a culture of data utilization, making it easier for stakeholders to rely on data for their decisions.\n\n4. **Feedback Loop Implementation**: Establishing a feedback loop allows the Senior Director to gather insights from stakeholders, which can be used to refine analytics processes. This continuous improvement ensures that the",
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   datetime.datetime(2024, 9, 17, 18, 9, 47, 983251),
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   0)]

# %% [markdown]
# **Convert the retrieved data to a dataframe.**

# %%
# Assign the appropriate column names
chatbot_column_names = ['agent_chatbot', 'answer', 'conversation_id', 'answer_timestamp', 'msg_id','position']

# Create a DataFrame
df_answer = pd.DataFrame([row for row in chatbot_msg], columns=chatbot_column_names)

# %%
df_answer
# Out:
#    agent_chatbot                                             answer  \
# 0        CHATBOT  I'm sorry, I could not find any information ab...
# 1        CHATBOT  Employee engagement refers to the emotional co...
# 2        CHATBOT  I'm sorry, I could not find any information ab...
# 3        CHATBOT  The Employee Assistance Program (EAP) provides...
# 4        CHATBOT  Tech Innovators Inc. offers training programs ...
# 5        CHATBOT  I'm sorry, I could not find any information ab...
# 6        CHATBOT  Tech Innovators Inc. has a zero-tolerance poli...
# 7        CHATBOT  [openai]: Adding a header image to a Confluenc...
# 8        CHATBOT  [openai]: Employee engagement and disengagemen...
# 9        CHATBOT  [openai]: Identifying growth areas in self-ass...
# 10       CHATBOT  [openai]: The Employee Assistance Program (EAP...
# 11       CHATBOT  [openai]: Tech Innovators Inc. offers a range ...
# 12       CHATBOT  [openai]: To enhance the onboarding process fo...
# 13       CHATBOT  [openai]: Tech Innovators Inc. has a zero-tole...
# 14       CHATBOT  [openai]: The purpose of adding a header image...
# 15       CHATBOT  I'm sorry, I couldn't find any information abo...
# 16       CHATBOT  Employee engagement refers to the emotional co...
# 17       CHATBOT  I'm sorry, I couldn't find any information abo...
# 18       CHATBOT  The Employee Assistance Program (EAP) provides...
# 19       CHATBOT  Tech Innovators Inc. offers training programs ...
# 20       CHATBOT  I'm sorry, I couldn't find any information abo...
# 21       CHATBOT  Tech Innovators Inc. has a zero-tolerance poli...
# 22       CHATBOT  Regular HR audits are conducted to ensure that...
# 23       CHATBOT  Sorry, I could not find any information about ...
# 24       CHATBOT  Employee engagement is characterized by motiva...
# 25       CHATBOT  Employees at Tech Innovators Inc. are responsi...
# 26       CHATBOT  Sorry, I could not find any information about ...
# 27       CHATBOT  Tech Innovators Inc. offers various types of l...
# 28       CHATBOT  Non-compliance with labor laws or company poli...
# 29       CHATBOT  Emotional and aesthetic labor involves managin...
# 30       CHATBOT  Tech Innovators Inc. strives to provide compre...
# 31       CHATBOT  HR audits are conducted regularly by the HR de...
# 32       CHATBOT  The RAG application uses the LangChain framewo...
# 33       CHATBOT  Employee engagement refers to the emotional co...
# 34       CHATBOT  Employees of Tech Innovators Inc. are responsi...
# 35       CHATBOT  Leadership plays an important role in employee...
# 36       CHATBOT  Tech Innovators Inc. offers several types of l...
# 37       CHATBOT  Non-compliance with labour laws or company pol...
# 38       CHATBOT  Emotional and aesthetic labour involves managi...
# 39       CHATBOT  The section on compensation and benefits shoul...
# 40       CHATBOT  [openai]: Adding a header image to a Confluenc...
# 41       CHATBOT  [openai]: Employee engagement and disengagemen...
# 42       CHATBOT  [openai]: Identifying growth areas in self-ass...
# 43       CHATBOT  [openai]: The Employee Assistance Program (EAP...
# 44       CHATBOT  [openai]: Tech Innovators Inc. offers a range ...
# 45       CHATBOT  [openai]: For new hires in the onboarding proc...
# 46       CHATBOT  [openai]: Tech Innovators Inc. has a zero-tole...
# 47       CHATBOT  [openai]: Tech Innovators Inc. promotes employ...
# 48       CHATBOT  [openai]: To extract data from Confluence and ...
# 49       CHATBOT  [openai]: Employee engagement and disengagemen...
# 50       CHATBOT  [openai]: At Tech Innovators Inc., there are s...
# 51       CHATBOT  [openai]: The purpose of the orientation sessi...
# 52       CHATBOT  [openai]: Emotional and aesthetic labor play a...
# 53       CHATBOT  [openai]: In the recruitment process of Inc., ...
# 54       CHATBOT  [openai]: Identifying and addressing growth ar...
# 55       CHATBOT  [openai]: The role of the Senior Director resp...
#
#                          conversation_id           answer_timestamp  \
# 0   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:15:00.653238
# 1   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:14:39.361201
# 2   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:14:20.792092
# 3   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:14:00.911699
# 4   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:13:43.733127
# 5   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:13:23.480350
# 6   71785d7b-4e05-4dee-b44d-4b5c025eb034 2024-09-25 16:12:55.734782
# 7   388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:46:26.820127
# 8   388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:45:42.033713
# 9   388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:45:13.526038
# 10  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:44:54.894356
# 11  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:44:14.135242
# 12  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:43:54.241425
# 13  388cf42c-9322-4f36-a896-850c98255e64 2024-09-25 15:42:39.701319
# 14  c209cc70-d03c-4439-87f9-224cd07d5da1 2024-09-24 22:45:26.109017
# 15  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:33:29.281308
# 16  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:31:34.146670
# 17  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:31:22.234875
# 18  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:31:05.227123
# 19  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:30:51.944807
# 20  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:30:36.960195
# 21  3dc7b09b-f7de-40f0-a7f0-1a8d46981531 2024-09-24 22:30:15.613587
# 22  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:22:45.332887
# 23  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:22:25.903597
# 24  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:22:00.752513
# 25  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:21:40.485097
# 26  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:21:26.098442
# 27  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:21:00.323130
# 28  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:39.290190
# 29  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:26.958788
# 30  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96 2024-09-18 18:20:09.007778
# 31  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:14:10.047930
# 32  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:13:42.283709
# 33  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:13:13.837793
# 34  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:59.118411
# 35  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:45.069947
# 36  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:22.259627
# 37  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:12:06.459099
# 38  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:11:53.741072
# 39  80db8675-6d68-42e9-949e-cd6a4a14c1f4 2024-09-18 18:11:13.580652
# 40  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:45:01.526985
# 41  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:49.006283
# 42  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:27.890469
# 43  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:44:09.997083
# 44  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:43:58.972825
# 45  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:43:46.027698
# 46  8117578e-d06a-4bfd-988f-b2eee28121f1 2024-09-17 21:43:29.170986
# 47  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:58.087223
# 48  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:45.436811
# 49  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:32.417639
# 50  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:18.736750
# 51  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:18:07.629822
# 52  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:55.927941
# 53  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:42.639361
# 54  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:17:21.233268
# 55  119128da-543a-4e36-b7f3-41fa2bebb6cb 2024-09-17 18:09:47.983251
#
#                                   msg_id  position
# 0   6974c089-42e7-4f32-995c-6f2aaa1f6330         6
# 1   a6232328-cdb5-483a-a1ad-18dfaed9d9bf         5
# 2   5f2caa0f-be6b-45c8-aa4b-16e93bec9964         4
# 3   c93def44-2a45-42c6-a851-d2a17c71a60c         3
# 4   3e5b362a-aaeb-447e-9ce6-65459534b6dd         2
# 5   dda7c255-077b-4c3e-b7ef-b68c4c756e61         1
# 6   c5f9334c-0ee0-4ce7-9d61-b08ea4d63ce2         0
# 7   b0964c50-62ff-4be0-b1f3-66c7382f8766         6
# 8   6a443923-2196-4c2e-bbcd-4cdab5bdd900         5
# 9   dd1f2dfa-0f24-4e92-89c1-ecc516aff34a         4
# 10  3a4e9d87-5af5-4763-bcaf-f998c79b2105         3
# 11  dd7dfc74-c310-45e9-a95b-67bd881f03ec         2
# 12  57295bde-27bc-4e49-9cc9-2f73a6374a46         1
# 13  62e3c8ea-710e-4ef4-b346-8ac0756e4953         0
# 14  2c13f405-00a5-4c3e-8904-1eb98694679c         0
# 15  558aa359-e8e9-420b-82be-ec64519c5cbb         6
# 16  7ea6dd99-b598-43af-b1c6-34c294a975a8         5
# 17  0aac496d-6960-416d-83e5-4e5dd6c3d7b5         4
# 18  2a766f13-19b8-4199-bd20-9acb70ac2fd9         3
# 19  535e0a18-7e13-46e5-8d67-aed6bca71dbb         2
# 20  e9042617-d990-4f3b-8e0c-5a765da17c7e         1
# 21  5cb6e630-1f81-466b-a351-f4ee7dd29f6d         0
# 22  99bcb13a-d816-4f11-a229-260411fc6ad6         8
# 23  6deab777-e339-4b13-b261-3a233e60f298         7
# 24  d929a278-9e27-42d9-b172-cd299fec2c04         6
# 25  3e45f825-7d55-48b9-b743-2f6e6ff735f2         5
# 26  81b7e1dc-e5d0-4a78-932c-12ee91b1debb         4
# 27  4b3f833e-c31d-4ca6-8488-6ff4ef46e076         3
# 28  a601b2c2-0fd9-41b2-9500-857d6b590e14         2
# 29  ea955e42-5db6-459b-a390-920164db800c         1
# 30  3e38e220-7904-4667-899b-a2495fd4d9a0         0
# 31  0aadd2ab-c0d5-40b5-ac98-7950f84152a0         8
# 32  51f57415-f2cf-4b63-bdfe-d1e852aa9a98         7
# 33  ffa56b29-5b36-4f13-a34e-1ab113ccfbb6         6
# 34  70d6e365-6dbd-4c5f-b2ff-467a6462cf05         5
# 35  6b95df96-65d4-43a6-8e41-aba045d28b42         4
# 36  cca2d60c-5826-4b71-a41e-c5df50cef119         3
# 37  7d63cf25-146b-4912-a0e0-ebfa7afeaf83         2
# 38  3ad7f0e5-156b-4db7-89a7-323b408ed67d         1
# 39  56389028-d5da-4079-8d62-efe3f223c93c         0
# 40  718f1b2d-af3a-4e0e-8b3c-251b687b763a         6
# 41  b9a78e51-e43c-4f2e-b9aa-e937a3bfacee         5
# 42  77467460-8250-4984-b81b-e40b3e576435         4
# 43  b0ffe91d-f84d-482d-adab-78646b7492f4         3
# 44  1717b0f9-9d53-441d-84b9-06299d6949b6         2
# 45  bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5         1
# 46  0d735817-2b82-449b-bb35-1a6b81be8148         0
# 47  bed1ac5d-6164-4924-97f5-5111509a5f8e         8
# 48  5d697220-b0fb-4fe0-a6f4-93c618568b25         7
# 49  d86faf67-d07c-497c-b760-39ff8eba131d         6
# 50  5337da38-0f84-4dd3-be38-3839ea9c16bf         5
# 51  d0f3a220-1b1f-4de8-81b2-4cfc73bdaf44         4
# 52  c98720a2-7457-4f8c-a9cf-857126cfbff0         3
# 53  7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95         2
# 54  cbf80b5e-76fd-4c8b-a8ac-146150452b65         1
# 55  80276b01-5a07-4be7-bb6a-470fa629315a         0

# %% [markdown]
# ### Contexts

# %%
# Fetch the context for the response if present
query_documents = """SELECT text, conversation_id, message_id, document_id 
        FROM public.documents
            ;"""

# Execute the query
cur.execute(query_documents)

# Fetch all results from the executed query
doc_result = cur.fetchall()
doc_result
# Out:
# [('the Senior Director responsible for Analytics Delivery, your role is critical to the success of Tech Innovators Inc. By leveraging your strategic vision, technical expertise, and leadership skills,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '0'),
#  ('the Senior Director responsible for Analytics Delivery, your role is critical to the success of Tech Innovators Inc. By leveraging your strategic vision, technical expertise, and leadership skills,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '1'),
#  ('the Senior Director responsible for Analytics Delivery, your role is critical to the success of Tech Innovators Inc. By leveraging your strategic vision, technical expertise, and leadership skills,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '2'),
#  ('the Senior Director responsible for Analytics Delivery, your role is critical to the success of Tech Innovators Inc. By leveraging your strategic vision, technical expertise, and leadership skills,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '3'),
#  ('IntroductionWelcome to Tech Innovators Inc. This training manual is designed for the Senior Director responsible for Analytics Delivery. It aims to provide a comprehensive overview of your role,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '4'),
#  ('IntroductionWelcome to Tech Innovators Inc. This training manual is designed for the Senior Director responsible for Analytics Delivery. It aims to provide a comprehensive overview of your role,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '5'),
#  ('IntroductionWelcome to Tech Innovators Inc. This training manual is designed for the Senior Director responsible for Analytics Delivery. It aims to provide a comprehensive overview of your role,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '6'),
#  ('IntroductionWelcome to Tech Innovators Inc. This training manual is designed for the Senior Director responsible for Analytics Delivery. It aims to provide a comprehensive overview of your role,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '7'),
#  ('of analytics initiatives.Feedback Loop: Implement a feedback loop to gather insights from stakeholders and continuously improve analytics processes and outcomes.ConclusionAs the Senior Director',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '8'),
#  ('of analytics initiatives.Feedback Loop: Implement a feedback loop to gather insights from stakeholders and continuously improve analytics processes and outcomes.ConclusionAs the Senior Director',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '80276b01-5a07-4be7-bb6a-470fa629315a',
#   '9'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '0'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '1'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '2'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '3'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '4'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '5'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '6'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '7'),
#  ('Employees are encouraged to take advantage of these opportunities and actively participate in their professional development.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '8'),
#  ('Employees are encouraged to take advantage of these opportunities and actively participate in their professional development.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'cbf80b5e-76fd-4c8b-a8ac-146150452b65',
#   '9'),
#  ('Inc. upholds the highest ethical standards in all recruitment activities.Implementation: Transparency and integrity are maintained throughout the recruitment process. Any form of unethical behavior,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '0'),
#  ('Inc. upholds the highest ethical standards in all recruitment activities.Implementation: Transparency and integrity are maintained throughout the recruitment process. Any form of unethical behavior,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '1'),
#  ('Inc. upholds the highest ethical standards in all recruitment activities.Implementation: Transparency and integrity are maintained throughout the recruitment process. Any form of unethical behavior,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '2'),
#  ('Inc. upholds the highest ethical standards in all recruitment activities.Implementation: Transparency and integrity are maintained throughout the recruitment process. Any form of unethical behavior,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '3'),
#  ('Inc. is an equal opportunity employer. We ensure all recruitment activities are conducted without discrimination based on race, color, religion, sex, national origin, age, disability, genetic',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '4'),
#  ('Inc. is an equal opportunity employer. We ensure all recruitment activities are conducted without discrimination based on race, color, religion, sex, national origin, age, disability, genetic',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '5'),
#  ('Inc. is an equal opportunity employer. We ensure all recruitment activities are conducted without discrimination based on race, color, religion, sex, national origin, age, disability, genetic',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '6'),
#  ('Inc. is an equal opportunity employer. We ensure all recruitment activities are conducted without discrimination based on race, color, religion, sex, national origin, age, disability, genetic',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '7'),
#  ('and Ethics6.1 Legal CompliancePolicy: All recruitment activities comply with applicable labor laws and regulations.Implementation: Regular audits and reviews of recruitment processes are conducted to',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '8'),
#  ('and Ethics6.1 Legal CompliancePolicy: All recruitment activities comply with applicable labor laws and regulations.Implementation: Regular audits and reviews of recruitment processes are conducted to',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95',
#   '9'),
#  ('LabourEmotional and aesthetic labor involves managing emotions and appearances to meet organizational expectations. While this can enhance customer experiences, it can also be taxing on employees. It',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '0'),
#  ('LabourEmotional and aesthetic labor involves managing emotions and appearances to meet organizational expectations. While this can enhance customer experiences, it can also be taxing on employees. It',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '1'),
#  ('LabourEmotional and aesthetic labor involves managing emotions and appearances to meet organizational expectations. While this can enhance customer experiences, it can also be taxing on employees. It',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '2'),
#  ('LabourEmotional and aesthetic labor involves managing emotions and appearances to meet organizational expectations. While this can enhance customer experiences, it can also be taxing on employees. It',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '3'),
#  ('and energy, burnout is marked by exhaustion and cynicism. Preventing burnout requires maintaining a healthy work-life balance and providing adequate support.\xa0Emotional and Aesthetic LabourEmotional',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '4'),
#  ('and energy, burnout is marked by exhaustion and cynicism. Preventing burnout requires maintaining a healthy work-life balance and providing adequate support.\xa0Emotional and Aesthetic LabourEmotional',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '5'),
#  ('and energy, burnout is marked by exhaustion and cynicism. Preventing burnout requires maintaining a healthy work-life balance and providing adequate support.\xa0Emotional and Aesthetic LabourEmotional',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '6'),
#  ('and energy, burnout is marked by exhaustion and cynicism. Preventing burnout requires maintaining a healthy work-life balance and providing adequate support.\xa0Emotional and Aesthetic LabourEmotional',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '7'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '8'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'c98720a2-7457-4f8c-a9cf-857126cfbff0',
#   '9'),
#  ('to help you get started.\xa0Company OverviewTech Innovators Inc. specializes in software development, IT consulting, and digital transformation services. Our mission is to drive innovation and deliver',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '4'),
#  ('to help you get started.\xa0Company OverviewTech Innovators Inc. specializes in software development, IT consulting, and digital transformation services. Our mission is to drive innovation and deliver',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '5'),
#  ('to help you get started.\xa0Company OverviewTech Innovators Inc. specializes in software development, IT consulting, and digital transformation services. Our mission is to drive innovation and deliver',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '6'),
#  ('to help you get started.\xa0Company OverviewTech Innovators Inc. specializes in software development, IT consulting, and digital transformation services. Our mission is to drive innovation and deliver',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '7'),
#  ('IntroductionWelcome to Tech Innovators Inc. This training manual is designed for the Senior Director responsible for Analytics Delivery. It aims to provide a comprehensive overview of your role,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '8'),
#  ('IntroductionWelcome to Tech Innovators Inc. This training manual is designed for the Senior Director responsible for Analytics Delivery. It aims to provide a comprehensive overview of your role,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '9'),
#  ('see you thrive at Tech Innovators Inc. Welcome aboard!\xa0For more detailed information, please refer to the HR Recruitment policies.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '0'),
#  ('see you thrive at Tech Innovators Inc. Welcome aboard!\xa0For more detailed information, please refer to the HR Recruitment policies.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '1'),
#  ('see you thrive at Tech Innovators Inc. Welcome aboard!\xa0For more detailed information, please refer to the HR Recruitment policies.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '2'),
#  ('see you thrive at Tech Innovators Inc. Welcome aboard!\xa0For more detailed information, please refer to the HR Recruitment policies.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd0f3a220-1b1f-4de8-81b2-4cfc73bdaf44',
#   '3'),
#  ('and identify areas for improvement.5.3 Reporting and InvestigationReporting Mechanism: Employees can report violations of labor laws or company policies through a confidential reporting system.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '0'),
#  ('and identify areas for improvement.5.3 Reporting and InvestigationReporting Mechanism: Employees can report violations of labor laws or company policies through a confidential reporting system.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '1'),
#  ('and identify areas for improvement.5.3 Reporting and InvestigationReporting Mechanism: Employees can report violations of labor laws or company policies through a confidential reporting system.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '2'),
#  ('and identify areas for improvement.5.3 Reporting and InvestigationReporting Mechanism: Employees can report violations of labor laws or company policies through a confidential reporting system.',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '3'),
#  ('Non-compliance can also expose the company to lawsuits and liability. Tech Innovators Inc. takes proactive measures to mitigate these risks through diligent compliance efforts.Employee',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '4'),
#  ('Non-compliance can also expose the company to lawsuits and liability. Tech Innovators Inc. takes proactive measures to mitigate these risks through diligent compliance efforts.Employee',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '5'),
#  ('Non-compliance can also expose the company to lawsuits and liability. Tech Innovators Inc. takes proactive measures to mitigate these risks through diligent compliance efforts.Employee',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '6'),
#  ('customersContact usHow can someone reach out to your team?✉️ Email address💬 ChatImportant PagesList them hereOnboarding FAQsAdd resources for new hiresMeeting notesAdd links to meeting notesTeam',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '7'),
#  ('Non-compliance can also expose the company to lawsuits and liability. Tech Innovators Inc. takes proactive measures to mitigate these risks through diligent compliance efforts.Employee',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '7'),
#  ('representative.Q12: What is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '8'),
#  ('representative.Q12: What is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5337da38-0f84-4dd3-be38-3839ea9c16bf',
#   '9'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '0'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '1'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '2'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '3'),
#  ('Engagement and BurnoutEngagement and burnout are often compared as they represent opposite ends of the employee experience spectrum. While engagement is characterized by enthusiasm and energy,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '8'),
#  ('Engagement and BurnoutEngagement and burnout are often compared as they represent opposite ends of the employee experience spectrum. While engagement is characterized by enthusiasm and energy,',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '9'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '4'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '5'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '6'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'd86faf67-d07c-497c-b760-39ff8eba131d',
#   '7'),
#  ('IntroductionThis guide provides a step-by-step process for creating a Retrieval-Augmented Generation (RAG) application using the LangChain framework. The application will be trained on custom data',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '0'),
#  ('IntroductionThis guide provides a step-by-step process for creating a Retrieval-Augmented Generation (RAG) application using the LangChain framework. The application will be trained on custom data',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '1'),
#  ('IntroductionThis guide provides a step-by-step process for creating a Retrieval-Augmented Generation (RAG) application using the LangChain framework. The application will be trained on custom data',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '2'),
#  ('IntroductionThis guide provides a step-by-step process for creating a Retrieval-Augmented Generation (RAG) application using the LangChain framework. The application will be trained on custom data',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '3'),
#  ('to the enterprise Confluence API or export files containing the Confluence data.Installation of necessary libraries and tools:LangChainOpenAI or Hugging Face TransformersPinecone or another vector',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '8'),
#  ('to the enterprise Confluence API or export files containing the Confluence data.Installation of necessary libraries and tools:LangChainOpenAI or Hugging Face TransformersPinecone or another vector',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '9'),
#  ('on custom data sourced from enterprise Confluence pages. RAG combines retrieval-based methods with generative models, leveraging both structured data and contextual understanding to generate accurate',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '4'),
#  ('on custom data sourced from enterprise Confluence pages. RAG combines retrieval-based methods with generative models, leveraging both structured data and contextual understanding to generate accurate',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '5'),
#  ('on custom data sourced from enterprise Confluence pages. RAG combines retrieval-based methods with generative models, leveraging both structured data and contextual understanding to generate accurate',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '6'),
#  ('on custom data sourced from enterprise Confluence pages. RAG combines retrieval-based methods with generative models, leveraging both structured data and contextual understanding to generate accurate',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   '5d697220-b0fb-4fe0-a6f4-93c618568b25',
#   '7'),
#  ('IntroductionAt Tech Innovators Inc., we believe that employee engagement is crucial to our success. This document provides a comprehensive overview of employee engagement, its critical aspects, and',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '4'),
#  ('IntroductionAt Tech Innovators Inc., we believe that employee engagement is crucial to our success. This document provides a comprehensive overview of employee engagement, its critical aspects, and',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '5'),
#  ('IntroductionAt Tech Innovators Inc., we believe that employee engagement is crucial to our success. This document provides a comprehensive overview of employee engagement, its critical aspects, and',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '6'),
#  ('IntroductionAt Tech Innovators Inc., we believe that employee engagement is crucial to our success. This document provides a comprehensive overview of employee engagement, its critical aspects, and',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '7'),
#  ('IntroductionTech Innovators Inc. is committed to fostering a diverse and inclusive workplace. Our recruitment policies are designed to ensure equal opportunities for all candidates, including those',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '0'),
#  ('IntroductionTech Innovators Inc. is committed to fostering a diverse and inclusive workplace. Our recruitment policies are designed to ensure equal opportunities for all candidates, including those',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '1'),
#  ('IntroductionTech Innovators Inc. is committed to fostering a diverse and inclusive workplace. Our recruitment policies are designed to ensure equal opportunities for all candidates, including those',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '2'),
#  ('IntroductionTech Innovators Inc. is committed to fostering a diverse and inclusive workplace. Our recruitment policies are designed to ensure equal opportunities for all candidates, including those',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '3'),
#  ('IntroductionTech Innovators Inc. strives to provide comprehensive payroll and benefits management to ensure that all employees are compensated fairly and provided with competitive benefits. This',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '8'),
#  ('IntroductionTech Innovators Inc. strives to provide comprehensive payroll and benefits management to ensure that all employees are compensated fairly and provided with competitive benefits. This',
#   '119128da-543a-4e36-b7f3-41fa2bebb6cb',
#   'bed1ac5d-6164-4924-97f5-5111509a5f8e',
#   '9'),
#  ('representative.Q12: What is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '0'),
#  ('representative.Q12: What is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '1'),
#  ('representative.Q12: What is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '2'),
#  ('representative.Q12: What is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '3'),
#  ('and adhere to EEO principles.2.2 Anti-Harassment and Anti-DiscriminationPolicy: Harassment or discrimination of any kind is not tolerated at Tech Innovators Inc. This includes sexual harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '4'),
#  ('and adhere to EEO principles.2.2 Anti-Harassment and Anti-DiscriminationPolicy: Harassment or discrimination of any kind is not tolerated at Tech Innovators Inc. This includes sexual harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '5'),
#  ('and adhere to EEO principles.2.2 Anti-Harassment and Anti-DiscriminationPolicy: Harassment or discrimination of any kind is not tolerated at Tech Innovators Inc. This includes sexual harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '6'),
#  ('and adhere to EEO principles.2.2 Anti-Harassment and Anti-DiscriminationPolicy: Harassment or discrimination of any kind is not tolerated at Tech Innovators Inc. This includes sexual harassment,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '7'),
#  ('promoting a fair and legal workplace.Employment Standards2.1 Equal Employment Opportunity (EEO)Policy: Tech Innovators Inc. is an equal opportunity employer. We do not discriminate based on race,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '8'),
#  ('promoting a fair and legal workplace.Employment Standards2.1 Equal Employment Opportunity (EEO)Policy: Tech Innovators Inc. is an equal opportunity employer. We do not discriminate based on race,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '0d735817-2b82-449b-bb35-1a6b81be8148',
#   '9'),
#  ('customersContact usHow can someone reach out to your team?✉️ Email address💬 ChatImportant PagesList them hereOnboarding FAQsAdd resources for new hiresMeeting notesAdd links to meeting notesTeam',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '4'),
#  ('customersContact usHow can someone reach out to your team?✉️ Email address💬 ChatImportant PagesList them hereOnboarding FAQsAdd resources for new hiresMeeting notesAdd links to meeting notesTeam',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '5'),
#  ('customersContact usHow can someone reach out to your team?✉️ Email address💬 ChatImportant PagesList them hereOnboarding FAQsAdd resources for new hiresMeeting notesAdd links to meeting notesTeam',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '6'),
#  ('and candidates are given adequate time to consider the offer. Onboarding includes a comprehensive orientation program to integrate new hires smoothly.Diversity and Inclusion Initiatives5.1 Diversity',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '0'),
#  ('and candidates are given adequate time to consider the offer. Onboarding includes a comprehensive orientation program to integrate new hires smoothly.Diversity and Inclusion Initiatives5.1 Diversity',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '1'),
#  ('and candidates are given adequate time to consider the offer. Onboarding includes a comprehensive orientation program to integrate new hires smoothly.Diversity and Inclusion Initiatives5.1 Diversity',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '2'),
#  ('and candidates are given adequate time to consider the offer. Onboarding includes a comprehensive orientation program to integrate new hires smoothly.Diversity and Inclusion Initiatives5.1 Diversity',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '3'),
#  ('seminars to help employees enhance their skills. Employees can access online courses, attend industry conferences, and participate in internal training sessions. Additionally, we provide resources',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '8'),
#  ('seminars to help employees enhance their skills. Employees can access online courses, attend industry conferences, and participate in internal training sessions. Additionally, we provide resources',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5',
#   '9'),
#  ('role in making data-driven decisions and gaining insights from complex datasets. Tech Innovators Inc. offers a range of training programs to build expertise in this critical area.3.2 Training',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '0'),
#  ('role in making data-driven decisions and gaining insights from complex datasets. Tech Innovators Inc. offers a range of training programs to build expertise in this critical area.3.2 Training',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '1'),
#  ('role in making data-driven decisions and gaining insights from complex datasets. Tech Innovators Inc. offers a range of training programs to build expertise in this critical area.3.2 Training',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '2'),
#  ('role in making data-driven decisions and gaining insights from complex datasets. Tech Innovators Inc. offers a range of training programs to build expertise in this critical area.3.2 Training',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '3'),
#  ('AI Courses: Access to specialized AI courses from platforms like Coursera, edX, and Udacity.Training in Other Business Functions5.1 OverviewIn addition to technical skills, Tech Innovators Inc.',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '8'),
#  ('AI Courses: Access to specialized AI courses from platforms like Coursera, edX, and Udacity.Training in Other Business Functions5.1 OverviewIn addition to technical skills, Tech Innovators Inc.',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '9'),
#  ('OverviewAI is transforming industries by automating tasks and providing intelligent insights. Tech Innovators Inc. offers training to help employees develop AI skills and apply them in business',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '4'),
#  ('OverviewAI is transforming industries by automating tasks and providing intelligent insights. Tech Innovators Inc. offers training to help employees develop AI skills and apply them in business',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '5'),
#  ('OverviewAI is transforming industries by automating tasks and providing intelligent insights. Tech Innovators Inc. offers training to help employees develop AI skills and apply them in business',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '6'),
#  ('OverviewAI is transforming industries by automating tasks and providing intelligent insights. Tech Innovators Inc. offers training to help employees develop AI skills and apply them in business',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '1717b0f9-9d53-441d-84b9-06299d6949b6',
#   '7'),
#  ('provides counseling services, legal advice, and financial planning assistance. Contact information for EAP is available on the HR portal.General PoliciesQ14: What is the company’s policy on remote',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '4'),
#  ('provides counseling services, legal advice, and financial planning assistance. Contact information for EAP is available on the HR portal.General PoliciesQ14: What is the company’s policy on remote',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '5'),
#  ('provides counseling services, legal advice, and financial planning assistance. Contact information for EAP is available on the HR portal.General PoliciesQ14: What is the company’s policy on remote',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '6'),
#  ('provides counseling services, legal advice, and financial planning assistance. Contact information for EAP is available on the HR portal.General PoliciesQ14: What is the company’s policy on remote',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '7'),
#  ('Who can I contact for confidential support?A13: Employees can contact the Employee Assistance Program (EAP) for confidential support on personal and professional issues. EAP provides counseling',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '0'),
#  ('Who can I contact for confidential support?A13: Employees can contact the Employee Assistance Program (EAP) for confidential support on personal and professional issues. EAP provides counseling',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '1'),
#  ('Who can I contact for confidential support?A13: Employees can contact the Employee Assistance Program (EAP) for confidential support on personal and professional issues. EAP provides counseling',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '2'),
#  ('Who can I contact for confidential support?A13: Employees can contact the Employee Assistance Program (EAP) for confidential support on personal and professional issues. EAP provides counseling',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '3'),
#  ('employees with any questions or concerns regarding their payroll and benefits. Employees can contact HR via email, phone, or in person during business hours.Employee Self-Service Portal: Employees',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '8'),
#  ('employees with any questions or concerns regarding their payroll and benefits. Employees can contact HR via email, phone, or in person during business hours.Employee Self-Service Portal: Employees',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b0ffe91d-f84d-482d-adab-78646b7492f4',
#   '9'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '0'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '0'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '1'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '2'),
#  ('to identify strengths and areas for improvement. Recruitment practices are evaluated annually, and updates are made based on feedback and changing business needs.7.2 Professional DevelopmentPolicy:',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '3'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '4'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '5'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '6'),
#  ('for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '7'),
#  ('Employees are encouraged to take advantage of these opportunities and actively participate in their professional development.',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '8'),
#  ('Description#F4F5F7In a sentence or two, describe the purpose of this space.Project Tracker\n\ncom.atlassian.confluence.project-linker\nproject-linker\ndefault\n3781a39a-e79f-41c1-a914-38846c22a77c',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '9'),
#  ('Employees are encouraged to take advantage of these opportunities and actively participate in their professional development.',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '77467460-8250-4984-b81b-e40b3e576435',
#   '9'),
#  ("InsertUseful elements for Team spaceIntroduce the teamAdd user profiles to display a short summary of a given Confluence user's profile with their role, profile photo and contact details.Share news",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '4'),
#  ("InsertUseful elements for Team spaceIntroduce the teamAdd user profiles to display a short summary of a given Confluence user's profile with their role, profile photo and contact details.Share news",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '5'),
#  ("InsertUseful elements for Team spaceIntroduce the teamAdd user profiles to display a short summary of a given Confluence user's profile with their role, profile photo and contact details.Share news",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '6'),
#  ("InsertUseful elements for Team spaceIntroduce the teamAdd user profiles to display a short summary of a given Confluence user's profile with their role, profile photo and contact details.Share news",
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '7'),
#  ('team is working on.Add a header image. This gives your overview visual appeal and makes it welcoming for visitors.Explain what the space is for. Start by summarizing the purpose of the space. This',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '0'),
#  ('team is working on.Add a header image. This gives your overview visual appeal and makes it welcoming for visitors.Explain what the space is for. Start by summarizing the purpose of the space. This',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '1'),
#  ('team is working on.Add a header image. This gives your overview visual appeal and makes it welcoming for visitors.Explain what the space is for. Start by summarizing the purpose of the space. This',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '2'),
#  ('team is working on.Add a header image. This gives your overview visual appeal and makes it welcoming for visitors.Explain what the space is for. Start by summarizing the purpose of the space. This',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '3'),
#  ('Description#F4F5F7In a sentence or two, describe the purpose of this space.Project Tracker\n\ncom.atlassian.confluence.project-linker\nproject-linker\ndefault\n3781a39a-e79f-41c1-a914-38846c22a77c',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   '718f1b2d-af3a-4e0e-8b3c-251b687b763a',
#   '8'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '1'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '2'),
#  ('are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '3'),
#  ('Engagement and BurnoutEngagement and burnout are often compared as they represent opposite ends of the employee experience spectrum. While engagement is characterized by enthusiasm and energy,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '8'),
#  ('Engagement and BurnoutEngagement and burnout are often compared as they represent opposite ends of the employee experience spectrum. While engagement is characterized by enthusiasm and energy,',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '9'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '4'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '5'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '6'),
#  ('aspects, and how we foster a collaborative and engaging work environment.\xa0What is Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization',
#   '8117578e-d06a-4bfd-988f-b2eee28121f1',
#   'b9a78e51-e43c-4f2e-b9aa-e937a3bfacee',
#   '7'),
#  ('IntroductionTech Innovators Inc. strives to provide comprehensive payroll and benefits management to ensure that all employees are compensated fairly and provided with competitive benefits. This document outlines the payroll and benefit management policies, processes, and procedures for our company.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   '56389028-d5da-4079-8d62-efe3f223c93c',
#   'mongodb_atlas:0:2:0'),
#  ('IntroductionTech Innovators Inc. strives to provide comprehensive payroll and benefits management to ensure that all employees are compensated fairly and provided with competitive benefits. This document outlines the payroll and benefit management policies, processes, and procedures for our company.',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   '56389028-d5da-4079-8d62-efe3f223c93c',
#   'mongodb_atlas:0:2:1'),
#  ('handbook provides detailed information about payroll and benefits policies and is distributed to all new hires during orientation.Regular Updates: Employees are informed of any changes to payroll and benefits policies through company-wide emails, meetings, and updates to the employee handbook.5.2',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   '56389028-d5da-4079-8d62-efe3f223c93c',
#   'mongodb_atlas:0:2:2'),
#  ('handbook provides detailed information about payroll and benefits policies and is distributed to all new hires during orientation.Regular Updates: Employees are informed of any changes to payroll and benefits policies through company-wide emails, meetings, and updates to the employee handbook.5.2',
#   '80db8675-6d68-42e9-949e-cd6a4a14c1f4',
#   '56389028-d5da-4079-8d62-efe3f223c93c',
#   'mongodb_atlas:0:2:3'),
# ...
#   '9'),
#  ('assessments are used to ensure a fair comparison of candidates. Diverse interview panels are established to mitigate bias.Recruitment Policies for Specific Groups3.1 People with Career BreaksPolicy: Tech Innovators Inc. recognizes the value of candidates who have taken career breaks and supports',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '0'),
#  ('tracks diversity metrics to monitor the effectiveness of recruitment policies and identify areas for improvement.Implementation: Regular reports on diversity metrics are reviewed by senior management. Recruitment strategies are adjusted based on these insights to ensure continuous improvement.5.2',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '2'),
#  ('about industry trends, market dynamics, and emerging technologies. Apply this knowledge to drive innovation in analytics delivery.Competitive Analysis: Conduct competitive analysis to identify opportunities and threats. Use insights to inform strategy and decision-making.4.2 Financial AcumenBudget',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '6'),
#  ('Improvement7.1 Feedback and EvaluationPolicy: Continuous improvement of recruitment policies and practices is essential to maintaining a competitive edge.Implementation: Feedback is regularly solicited from candidates and hiring managers to identify strengths and areas for improvement. Recruitment',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '1'),
#  ("testing and refinement will ensure the application's robustness and effectiveness.",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '3'),
#  ('continuous learning and professional development.Innovation: Promote a culture of innovation where new ideas and approaches are encouraged and tested.6.2 Performance MetricsKPIs: Define and monitor key performance indicators (KPIs) to measure the success of analytics initiatives.Feedback Loop:',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '5'),
#  ('SupportMentorship: Connect with your assigned mentor for guidance and support.Feedback: Provide and receive feedback regularly to ensure continuous improvement.Professional Development: Take advantage of professional development opportunities.\xa0Important ContactsHR Department:',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '8'),
#  ("a clear vision and provides support.Work Environment: A positive and inclusive work environment that fosters collaboration.Recognition: Regular recognition and appreciation of employees' efforts.Development Opportunities: Access to professional growth and development opportunities.\xa0Employment",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '4'),
#  ('Foster a collaborative environment where cross-functional teams work together to achieve common goals.Continuous Improvement6.1 Innovation and LearningContinuous Learning: Stay updated with the latest advancements in analytics and related fields. Encourage the team to pursue continuous learning and',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '7'),
#  ('to your manager outlining the benefits of the certification and how it aligns with your career goals and the company’s objectives.Q3: How can I apply for internal training programs?A3: Internal training programs are announced via the company’s internal communication channels, such as the intranet',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'dd1f2dfa-0f24-4e92-89c1-ecc516aff34a',
#   '9'),
#  ('Description#F4F5F7In a sentence or two, describe the purpose of this space.Project Tracker\n\ncom.atlassian.confluence.project-linker\nproject-linker\ndefault\n3781a39a-e79f-41c1-a914-38846c22a77c',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '0'),
#  ('enterprise Confluence API or export files containing the Confluence data.Installation of necessary libraries and tools:LangChainOpenAI or Hugging Face TransformersPinecone or another vector database for retrievalConfluence API library (e.g., atlassian-python-api)Setting Up the Environment3.1',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '3'),
#  ('Recently updated contentThis list below will automatically update each time somebody in your space creates or updates content.page,whiteboard,database,blog10concisetrueContributorsThis list below will automatically update each time somebody in your space creates or updates content.descendants10',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '4'),
#  ('Description#F4F5F7In a sentence or two, describe the purpose of this space.Search this SpaceFilter by LabelThese are all the labels in use in this space. Select a label to see a list of content the label has been applied to.Recently updated contentThis list below will automatically update each time',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '1'),
#  ('update each time somebody in your space creates or updates content.page,whiteboard,database,blog10concisetrue',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '6'),
#  ('Confirmation:Created by: IT Support TeamLast Updated by: Jane Smith on July 20, 2024, 11:00 AM',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '5'),
#  ('and disengagement are two sides of the same coin. While engaged employees are motivated and committed, disengaged employees may feel disconnected and unmotivated. It is essential to identify signs of disengagement early and address them proactively.\xa0Comparing Engagement and BurnoutEngagement and',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '2'),
#  ("Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization and its goals. Engaged employees are enthusiastic about their work, take positive action to further the organization's reputation and interests, and are motivated to contribute to",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '0'),
#  ('and Employee EngagementThe organizational climate significantly impacts employee engagement. A positive climate characterized by trust, respect, and support fosters higher engagement levels. Conversely, a negative climate can lead to disengagement and high turnover rates.\xa0Employee Engagement in',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '5'),
#  ('and BurnoutEngagement and burnout are often compared as they represent opposite ends of the employee experience spectrum. While engagement is characterized by enthusiasm and energy, burnout is marked by exhaustion and cynicism. Preventing burnout requires maintaining a healthy work-life balance and',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '7'),
#  ('and management.Employee Involvement: Involving employees in decision-making processes and seeking their input on matters that affect them.Supportive Culture: Creating a supportive culture where employees feel valued and respected.\xa0Engagement and DisengagementEngagement and disengagement are two',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '3'),
#  ('motivated to contribute to its success.\xa0Critical Review of Employee EngagementWhile employee engagement is widely recognized as beneficial, it is essential to critically review its implications. Overemphasis on engagement without addressing underlying issues can lead to burnout and dissatisfaction.',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '4'),
#  ("employees. It is important to recognize and support employees' emotional well-being.\xa0Measuring Employee EngagementMeasuring employee engagement involves assessing various factors such as job satisfaction, commitment, and motivation. Common methods include:Surveys: Regular employee engagement",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '1'),
#  ('burnout and dissatisfaction. It is crucial to balance engagement initiatives with realistic expectations and support systems.\xa0Antecedents to Employee EngagementSeveral factors contribute to employee engagement, including:Leadership: Effective leadership that communicates a clear vision and provides',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '8'),
#  ('rates.\xa0Employee Engagement in Times of ChangeDuring times of change, maintaining employee engagement is critical. This involves:Clear Communication: Providing clear and consistent communication about changes and their impact.Support Systems: Offering support systems to help employees navigate',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '6'),
#  ('necessary information and guidance.Compliance: Employees must adhere to all labor laws and company policies. Failure to do so may result in disciplinary action and affect their employment status.7.2 Reporting ViolationsDuty to Report: Employees have a duty to report any violations of labor laws or',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   '6a443923-2196-4c2e-bbcd-4cdab5bdd900',
#   '9'),
#  ('framework trained on custom data from enterprise Confluence pages. This application leverages both retrieval and generative capabilities to provide accurate and contextually relevant responses, enhancing the overall decision-making process within your organization. Continuous testing and refinement',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '2'),
#  ('Foster a collaborative environment where cross-functional teams work together to achieve common goals.Continuous Improvement6.1 Innovation and LearningContinuous Learning: Stay updated with the latest advancements in analytics and related fields. Encourage the team to pursue continuous learning and',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '7'),
#  ("a clear vision and provides support.Work Environment: A positive and inclusive work environment that fosters collaboration.Recognition: Regular recognition and appreciation of employees' efforts.Development Opportunities: Access to professional growth and development opportunities.\xa0Employment",
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '9'),
#  ('to fostering an engaging work environment through open communication, recognition, and support. By understanding and addressing the various aspects of engagement, we can create a thriving workplace where employees feel valued and motivated.\xa0For more information or questions regarding our employee',
#   '388cf42c-9322-4f36-a896-850c98255e64',
#   'b0964c50-62ff-4be0-b1f3-66c7382f8766',
#   '8'),
#  ('is the process for handling workplace harassment?A12: Tech Innovators Inc. has a zero-tolerance policy for workplace harassment. If you experience or witness harassment, report it immediately to HR or your manager. The company will conduct a thorough investigation and take appropriate action to',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'c5f9334c-0ee0-4ce7-9d61-b08ea4d63ce2',
#   'mongodb_atlas:0:2:0'),
#  ('on merit and business needs. The company conducts regular training to ensure all employees understand and adhere to EEO principles.2.2 Anti-Harassment and Anti-DiscriminationPolicy: Harassment or discrimination of any kind is not tolerated at Tech Innovators Inc. This includes sexual harassment,',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'c5f9334c-0ee0-4ce7-9d61-b08ea4d63ce2',
#   'mongodb_atlas:0:2:1'),
#  ('Offers are extended promptly, and candidates are given adequate time to consider the offer. Onboarding includes a comprehensive orientation program to integrate new hires smoothly.Diversity and Inclusion Initiatives5.1 Diversity MetricsPolicy: Tech Innovators Inc. tracks diversity metrics to',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'dda7c255-077b-4c3e-b7ef-b68c4c756e61',
#   'mongodb_atlas:0:5:0'),
#  ('training programs in cloud computing, data science, AI, and other business functions, we aim to empower our workforce with the skills and knowledge needed to drive innovation and achieve excellence. Employees are encouraged to take advantage of these opportunities and actively participate in their',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   '3e5b362a-aaeb-447e-9ce6-65459534b6dd',
#   'mongodb_atlas:0:8:0'),
#  ('critical area.3.2 Training ProgramsIntroduction to Data Science: This course introduces the fundamental concepts of data science, including data exploration, data cleaning, and basic statistical analysis.Data Analysis and Visualization: Employees will learn to analyze and visualize data using tools',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   '3e5b362a-aaeb-447e-9ce6-65459534b6dd',
#   'mongodb_atlas:0:8:1'),
#  ('take appropriate action to ensure a safe and respectful workplace.Q13: Who can I contact for confidential support?A13: Employees can contact the Employee Assistance Program (EAP) for confidential support on personal and professional issues. EAP provides counseling services, legal advice, and',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'c93def44-2a45-42c6-a851-d2a17c71a60c',
#   'mongodb_atlas:0:11:0'),
#  ('services, legal advice, and financial planning assistance. Contact information for EAP is available on the HR portal.General PoliciesQ14: What is the company’s policy on remote work?A14: Tech Innovators Inc. supports flexible working arrangements, including remote work. Employees can work remotely',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'c93def44-2a45-42c6-a851-d2a17c71a60c',
#   'mongodb_atlas:0:11:1'),
#  ('Description#F4F5F7In a sentence or two, describe the purpose of this space.Project Tracker com.atlassian.confluence.project-linker project-linker default 3781a39a-e79f-41c1-a914-38846c22a77c',
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   '6974c089-42e7-4f32-995c-6f2aaa1f6330',
#   'mongodb_atlas:0:20:0'),
#  ("Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization and its goals. Engaged employees are enthusiastic about their work, take positive action to further the organization's reputation and interests, and are motivated to contribute to",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'a6232328-cdb5-483a-a1ad-18dfaed9d9bf',
#   'mongodb_atlas:0:17:0'),
#  ("employees. It is important to recognize and support employees' emotional well-being. Measuring Employee EngagementMeasuring employee engagement involves assessing various factors such as job satisfaction, commitment, and motivation. Common methods include:Surveys: Regular employee engagement",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'a6232328-cdb5-483a-a1ad-18dfaed9d9bf',
#   'mongodb_atlas:0:17:1'),
#  ("Employee Engagement?Employee engagement refers to the emotional commitment an employee has towards their organization and its goals. Engaged employees are enthusiastic about their work, take positive action to further the organization's reputation and interests, and are motivated to contribute to",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'a6232328-cdb5-483a-a1ad-18dfaed9d9bf',
#   'mongodb_atlas:1:17:0'),
#  ("employees. It is important to recognize and support employees' emotional well-being. Measuring Employee EngagementMeasuring employee engagement involves assessing various factors such as job satisfaction, commitment, and motivation. Common methods include:Surveys: Regular employee engagement",
#   '71785d7b-4e05-4dee-b44d-4b5c025eb034',
#   'a6232328-cdb5-483a-a1ad-18dfaed9d9bf',
#   'mongodb_atlas:1:17:1')]

# %% [markdown]
# **Convert the retrieved data to a dataframe.**

# %%
# Assign the appropriate column names
docs_column_names = ['contexts', 'conversation_id', 'msg_id', 'doc_id']

# Create a DataFrame
df_docs = pd.DataFrame([row for row in doc_result], columns=docs_column_names)

# %%
# Group by 'conversation_id' and 'msg_id' and combine 'content' as a list
df_contexts = df_docs.groupby(['conversation_id','msg_id'])['contexts'].apply(list).reset_index()

# %%
df_contexts
# Out:
#                          conversation_id  \
# 0   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 1   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 2   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 3   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 4   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 5   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 6   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 7   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 8   119128da-543a-4e36-b7f3-41fa2bebb6cb
# 9   388cf42c-9322-4f36-a896-850c98255e64
# 10  388cf42c-9322-4f36-a896-850c98255e64
# 11  388cf42c-9322-4f36-a896-850c98255e64
# 12  388cf42c-9322-4f36-a896-850c98255e64
# 13  388cf42c-9322-4f36-a896-850c98255e64
# 14  388cf42c-9322-4f36-a896-850c98255e64
# 15  388cf42c-9322-4f36-a896-850c98255e64
# 16  3dc7b09b-f7de-40f0-a7f0-1a8d46981531
# 17  3dc7b09b-f7de-40f0-a7f0-1a8d46981531
# 18  3dc7b09b-f7de-40f0-a7f0-1a8d46981531
# 19  3dc7b09b-f7de-40f0-a7f0-1a8d46981531
# 20  3dc7b09b-f7de-40f0-a7f0-1a8d46981531
# 21  3dc7b09b-f7de-40f0-a7f0-1a8d46981531
# 22  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 23  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 24  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 25  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 26  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 27  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 28  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 29  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 30  71189b05-eb1c-4c08-b4fc-7d90cc9f3b96
# 31  71785d7b-4e05-4dee-b44d-4b5c025eb034
# 32  71785d7b-4e05-4dee-b44d-4b5c025eb034
# 33  71785d7b-4e05-4dee-b44d-4b5c025eb034
# 34  71785d7b-4e05-4dee-b44d-4b5c025eb034
# 35  71785d7b-4e05-4dee-b44d-4b5c025eb034
# 36  71785d7b-4e05-4dee-b44d-4b5c025eb034
# 37  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 38  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 39  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 40  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 41  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 42  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 43  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 44  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 45  80db8675-6d68-42e9-949e-cd6a4a14c1f4
# 46  8117578e-d06a-4bfd-988f-b2eee28121f1
# 47  8117578e-d06a-4bfd-988f-b2eee28121f1
# 48  8117578e-d06a-4bfd-988f-b2eee28121f1
# 49  8117578e-d06a-4bfd-988f-b2eee28121f1
# 50  8117578e-d06a-4bfd-988f-b2eee28121f1
# 51  8117578e-d06a-4bfd-988f-b2eee28121f1
# 52  8117578e-d06a-4bfd-988f-b2eee28121f1
# 53  c209cc70-d03c-4439-87f9-224cd07d5da1
#
#                                   msg_id  \
# 0   5337da38-0f84-4dd3-be38-3839ea9c16bf
# 1   5d697220-b0fb-4fe0-a6f4-93c618568b25
# 2   7f03ffa6-b3d7-4428-a2a1-5a0fe53cab95
# 3   80276b01-5a07-4be7-bb6a-470fa629315a
# 4   bed1ac5d-6164-4924-97f5-5111509a5f8e
# 5   c98720a2-7457-4f8c-a9cf-857126cfbff0
# 6   cbf80b5e-76fd-4c8b-a8ac-146150452b65
# 7   d0f3a220-1b1f-4de8-81b2-4cfc73bdaf44
# 8   d86faf67-d07c-497c-b760-39ff8eba131d
# 9   3a4e9d87-5af5-4763-bcaf-f998c79b2105
# 10  57295bde-27bc-4e49-9cc9-2f73a6374a46
# 11  62e3c8ea-710e-4ef4-b346-8ac0756e4953
# 12  6a443923-2196-4c2e-bbcd-4cdab5bdd900
# 13  b0964c50-62ff-4be0-b1f3-66c7382f8766
# 14  dd1f2dfa-0f24-4e92-89c1-ecc516aff34a
# 15  dd7dfc74-c310-45e9-a95b-67bd881f03ec
# 16  2a766f13-19b8-4199-bd20-9acb70ac2fd9
# 17  535e0a18-7e13-46e5-8d67-aed6bca71dbb
# 18  558aa359-e8e9-420b-82be-ec64519c5cbb
# 19  5cb6e630-1f81-466b-a351-f4ee7dd29f6d
# 20  7ea6dd99-b598-43af-b1c6-34c294a975a8
# 21  e9042617-d990-4f3b-8e0c-5a765da17c7e
# 22  3e38e220-7904-4667-899b-a2495fd4d9a0
# 23  3e45f825-7d55-48b9-b743-2f6e6ff735f2
# 24  4b3f833e-c31d-4ca6-8488-6ff4ef46e076
# 25  6deab777-e339-4b13-b261-3a233e60f298
# 26  81b7e1dc-e5d0-4a78-932c-12ee91b1debb
# 27  99bcb13a-d816-4f11-a229-260411fc6ad6
# 28  a601b2c2-0fd9-41b2-9500-857d6b590e14
# 29  d929a278-9e27-42d9-b172-cd299fec2c04
# 30  ea955e42-5db6-459b-a390-920164db800c
# 31  3e5b362a-aaeb-447e-9ce6-65459534b6dd
# 32  6974c089-42e7-4f32-995c-6f2aaa1f6330
# 33  a6232328-cdb5-483a-a1ad-18dfaed9d9bf
# 34  c5f9334c-0ee0-4ce7-9d61-b08ea4d63ce2
# 35  c93def44-2a45-42c6-a851-d2a17c71a60c
# 36  dda7c255-077b-4c3e-b7ef-b68c4c756e61
# 37  0aadd2ab-c0d5-40b5-ac98-7950f84152a0
# 38  3ad7f0e5-156b-4db7-89a7-323b408ed67d
# 39  51f57415-f2cf-4b63-bdfe-d1e852aa9a98
# 40  56389028-d5da-4079-8d62-efe3f223c93c
# 41  6b95df96-65d4-43a6-8e41-aba045d28b42
# 42  70d6e365-6dbd-4c5f-b2ff-467a6462cf05
# 43  7d63cf25-146b-4912-a0e0-ebfa7afeaf83
# 44  cca2d60c-5826-4b71-a41e-c5df50cef119
# 45  ffa56b29-5b36-4f13-a34e-1ab113ccfbb6
# 46  0d735817-2b82-449b-bb35-1a6b81be8148
# 47  1717b0f9-9d53-441d-84b9-06299d6949b6
# 48  718f1b2d-af3a-4e0e-8b3c-251b687b763a
# 49  77467460-8250-4984-b81b-e40b3e576435
# 50  b0ffe91d-f84d-482d-adab-78646b7492f4
# 51  b9a78e51-e43c-4f2e-b9aa-e937a3bfacee
# 52  bd2f1bd6-5d08-47b4-ba1a-280b69c0f9c5
# 53  2c13f405-00a5-4c3e-8904-1eb98694679c
#
#                                              contexts
# 0   [and identify areas for improvement.5.3 Report...
# 1   [IntroductionThis guide provides a step-by-ste...
# 2   [Inc. upholds the highest ethical standards in...
# 3   [the Senior Director responsible for Analytics...
# 4   [IntroductionAt Tech Innovators Inc., we belie...
# 5   [LabourEmotional and aesthetic labor involves ...
# 6   [to identify strengths and areas for improveme...
# 7   [to help you get started. Company OverviewTech...
# 8   [are motivated and committed, disengaged emplo...
# 9   [and reach out to HR with any questions or con...
# 10  [Offers are extended promptly, and candidates ...
# 11  [is the process for handling workplace harassm...
# 12  [and disengagement are two sides of the same c...
# 13  [Description#F4F5F7In a sentence or two, descr...
# 14  [assessments are used to ensure a fair compari...
# 15  [experience with cloud platforms and tools.Tra...
# 16  [take appropriate action to ensure a safe and ...
# 17  [training programs in cloud computing, data sc...
# 18  [Description#F4F5F7In a sentence or two, descr...
# 19  [is the process for handling workplace harassm...
# 20  [Employee Engagement?Employee engagement refer...
# 21  [Offers are extended promptly, and candidates ...
# 22  [IntroductionTech Innovators Inc. strives to p...
# 23  [mitigate these risks through diligent complia...
# 24  [Inc. offers various types of leaves including...
# 25  [IntroductionThis guide provides a step-by-ste...
# 26  [motivated to contribute to its success. Criti...
# 27  [are conducted to ensure employees and manager...
# 28  [findings reported to senior management.Conseq...
# 29  [and disengagement are two sides of the same c...
# 30  [healthy work-life balance and providing adequ...
# 31  [training programs in cloud computing, data sc...
# 32  [Description#F4F5F7In a sentence or two, descr...
# 33  [Employee Engagement?Employee engagement refer...
# 34  [is the process for handling workplace harassm...
# 35  [take appropriate action to ensure a safe and ...
# 36  [Offers are extended promptly, and candidates ...
# 37  [are conducted to ensure employees and manager...
# 38  [healthy work-life balance and providing adequ...
# 39  [IntroductionThis guide provides a step-by-ste...
# 40  [IntroductionTech Innovators Inc. strives to p...
# 41  [opportunities. Employment Relations and Engag...
# 42  [IntroductionTech Innovators Inc. is committed...
# 43  [findings reported to senior management.Conseq...
# 44  [IntroductionTech Innovators Inc. is committed...
# 45  [Employee Engagement?Employee engagement refer...
# 46  [representative.Q12: What is the process for h...
# 47  [role in making data-driven decisions and gain...
# 48  [Description#F4F5F7In a sentence or two, descr...
# 49  [to identify strengths and areas for improveme...
# 50  [provides counseling services, legal advice, a...
# 51  [are motivated and committed, disengaged emplo...
# 52  [customersContact usHow can someone reach out ...
# 53  [InsertUseful elements for Team spaceIntroduce...

# %% [markdown]
# # Prepare data for evaluation

# %%
# Perform a merge between the answers dataframe and contexts dataframe using 'conversation_id' and 'msg_id'
df_answer_contexts = pd.merge(df_answer, df_contexts, on=['conversation_id', 'msg_id'], how='left')

# %%
# Merge the resulting dataframe with question dataframe using conversation_id and position
df_question_answer_contexts = pd.merge(df_question, df_answer_contexts, on=['conversation_id', 'position'], how='inner')

# %% [markdown]
# # Save data for evaluation

# %% [markdown]
# **The contexts column of the final dataframe has a data type list. We need a function to serialize it before saving the dataframe to a csv file, and a de-serialize function to read a csv file with a list column**

# %%
import json
import pandas as pd

def serialize_list(value):
    """Serializes a list to a JSON string."""
    return json.dumps(value)

def deserialize_list(value):
    """Deserializes a JSON string back into a list."""
    return json.loads(value)

def save_dataframe_with_list_column(df, filename):
    """Saves a DataFrame with a list column to a CSV file, preserving the list structure.

    Args:
        df: The DataFrame to save.
        filename: The name of the output CSV file.
    """

    # Apply the serialization function to the list column
    df['contexts'] = df['contexts'].apply(serialize_list)

    # Save the DataFrame to CSV
    df.to_csv(filename, index=False)

def load_dataframe_with_list_column(filename):
    """Loads a DataFrame from a CSV file, restoring the list structure.

    Args:
        filename: The name of the input CSV file.

    Returns:
        The loaded DataFrame.
    """

    # Load the DataFrame
    df = pd.read_csv(filename)

    # Apply the deserialization function to the list column
    df['contexts'] = df['contexts'].apply(deserialize_list)

    return df

# %% [markdown]
# **Save the result dataframe to a csv file for evaluation.**

# %%
# from from_root import from_root

# file_name = "<your_file_name>"

# save_dataframe_with_list_column(df_question_answer_contexts_<filter_this dataframe_as_you_need>, 'your_path_to_save_this_file>', file_name))

# %% [markdown]
# **Examples.**

# %% [markdown]
# **Export data for OpenAI deployment test.**

# %%
# Export the data to a csv file
from from_root import from_root
file_name = "test_dataset_hr_openai_deployment_test.csv"
save_dataframe_with_list_column(df_question_answer_contexts[df_question_answer_contexts['conversation_id']=='388cf42c-9322-4f36-a896-850c98255e64'][['question', 'answer', 'contexts']], os.path.join(from_root(), "data-test/test-dataset/", file_name))

# %% [markdown]
# **Export data for Cohere deployment test.**

# %%
# Filter the dataframe using conversation_id
data_to_export = df_question_answer_contexts[df_question_answer_contexts['conversation_id']=='71785d7b-4e05-4dee-b44d-4b5c025eb034'][['question', 'answer', 'contexts']]

# %%
# Address the NaN values in contexts
data_to_export.loc[2,'contexts'] = ['No context']

# %%
# Export the data to a csv file
from from_root import from_root
file_name = "test_dataset_hr_cohere_deployment_test.csv"
save_dataframe_with_list_column(data_to_export, os.path.join(from_root(), "data-test/test-dataset/", file_name))

# %% [markdown]
# **Export data for post-production evaluation.**

# %%
# Export the data to a csv file
from from_root import from_root
file_name = "test_dataset_it_openai_deployment_post_prod.csv"
save_dataframe_with_list_column(df_question_answer_contexts[df_question_answer_contexts['conversation_id']=='8117578e-d06a-4bfd-988f-b2eee28121f1'], os.path.join(from_root(), "data-test/test-dataset/", file_name))
# Out:
# C:\Users\dqmin\AppData\Local\Temp\ipykernel_30096\3972522625.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['contexts'] = df['contexts'].apply(serialize_list)
